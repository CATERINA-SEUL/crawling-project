# %% [markdown]
# ## 티빙VOD 크롤링

# %% [markdown]
# ### 프로젝트생성

# %%
# !scrapy startproject tving_vod
# Out:
# New Scrapy project 'tving_vod', using template directory '/home/ubuntu/.pyenv/versions/3.6.9/envs/python3/lib/python3.6/site-packages/scrapy/templates/project', created in:
#     /home/ubuntu/notebook/Project_crawling/tving_vod
#
# You can start your first spider with:
#     cd tving_vod
#     scrapy genspider example example.com

# %% [markdown]
# ### items.py 수정

# %%
# !cat tving_vod/tving_vod/items.py
# Out:
# # -*- coding: utf-8 -*-
#
# # Define here the models for your scraped items
# #
# # See documentation in:
# # https://docs.scrapy.org/en/latest/topics/items.html
#
# import scrapy
#
#
# class TvingVodItem(scrapy.Item):
#     # define the fields for your item here like:
#     # name = scrapy.Field()
#     pass

# %%
% % writefile tving_vod/tving_vod/items.py
import scrapy

class TvingVodItem(scrapy.Item):
    program = scrapy.Field()
    title = scrapy.Field()
    genre = scrapy.Field()
    broadcast_date = scrapy.Field()
    channel = scrapy.Field()
    view_day = scrapy.Field()
    view_week = scrapy.Field()
    sale_day = scrapy.Field()
    sale_week = scrapy.Field()
    p_url = scrapy.Field()
# Out:
# Overwriting tving_vod/tving_vod/items.py

# %% [markdown]
# ### spider.py 생성

# %%
% % writefile tving_vod/tving_vod/spiders/spider.py
from tving_vod.items import TvingVodItem
import json
import scrapy

class Spider(scrapy.Spider):
    name = "TvingVod"
    allow_domain = ['tiving.com']
    start_urls = ['http://www.tving.com/vod/popular']

    def parse(self, response):
        apiKey = response.text.split('apiKey=')[1].split("&")[0]
        pageSize = 100
        url = "https://api.tving.com/v2/media/episodes?pageNo=1&pageSize={}&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey={}".format(
            pageSize, apiKey)
        yield scrapy.Request(url, callback=self.get_content)

    def get_content(self, response):

        for data in json.loads(response.body_as_unicode())['body']['result']:
            program = data['program']['name']['ko']
            title = data['vod_name']['ko']
            genre = data['program']['category1_name']['ko']
            broadcast_date = data['episode']['broadcast_date']
            channel = data['channel']['name']['ko']
            actor = data['program']['actor']
            view_day = data['view_count']['day']
            view_week = data['view_count']['week']
            sale_day = data['sale_count']['day']
            sale_week = data['sale_count']['week']
            p_url = "http://www.tving.com/vod/player/" + data['vod_code']

            item = TvingVodItem()
            item['program'] = program
            item['title'] = title
            item['genre'] = genre
            item['broadcast_date'] = broadcast_date
            item['channel'] = channel
            item['view_day'] = view_day
            item['view_week'] = view_week
            item['sale_day'] = sale_day
            item['sale_week'] = sale_week
            item['p_url'] = p_url

            yield item
# Out:
# Overwriting tving_vod/tving_vod/spiders/spider.py

# %% [markdown]
# ### models.py 작성

# %%
% % writefile tving_vod/tving_vod/models.py
from scrapy.utils.project import get_project_settings
from sqlalchemy import Integer, Text
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import create_engine, Column, Table, ForeignKey, MetaData

DeclarativeBase = declarative_base()


def db_connect():
    """
    Performs database connection using database settings from settings.py.
    Returns sqlalchemy engine instance
    """
    return create_engine(get_project_settings().get("CONNECTION_STRING"))


def create_table(engine):
    DeclarativeBase.metadata.create_all(engine)


class TvingVodDB(DeclarativeBase):
    __tablename__ = "TvingVod"

    id = Column(Integer, primary_key=True)
    program = Column('program', Text)
    title = Column('title', Text)
    genre = Column('genre', Text)
    broadcast_date = Column('broadcast_date', Text)
    channel = Column('channel', Text)
    view_day = Column('view_day', Integer)
    view_week = Column('view_week', Integer)
    sale_day = Column('sale_day', Integer)
    sale_week = Column('sale_week', Integer)
# Out:
# Overwriting tving_vod/tving_vod/models.py

# %% [markdown]
# ### pipeline 연결

# %%
% % writefile tving_vod/tving_vod/pipelines.py
from tving_vod.models import TvingVodDB, db_connect, create_table
from sqlalchemy.orm import sessionmaker

class TvingVodPipeline(object):
    def __init__(self):
        """
        Initializes database connection and sessionmaker.
        Creates deals table.
        """
        engine = db_connect()
        create_table(engine)
        self.Session = sessionmaker(bind=engine)

    def process_item(self, item, spider):
        """Save deals in the database.

        This method is called for every item pipeline component.
        """
        session = self.Session()
        tvingvoddb = TvingVodDB()
        tvingvoddb.program = item["program"]
        tvingvoddb.title = item["title"]
        tvingvoddb.genre = item["genre"]
        tvingvoddb.broadcast_date = item["broadcast_date"]
        tvingvoddb.channel = item["channel"]
        tvingvoddb.view_day = item["view_day"]
        tvingvoddb.view_week = item["view_week"]
        tvingvoddb.sale_day = item["sale_day"]
        tvingvoddb.sale_week = item["sale_week"]
        tvingvoddb.p_url = item["p_url"]

        try:
            session.add(tvingvoddb)
            session.commit()
        except:
            session.rollback()
            raise
        finally:
            session.close()

        return item
# Out:
# Overwriting tving_vod/tving_vod/pipelines.py

# %% [markdown]
# ### settings.py 수정 : ROBOTSTXT_OBEY = FALSE로

# %%
# !sed - i 's/ROBOTSTXT_OBEY = True/ROBOTSTXT_OBEY = False/' tving_vod/tving_vod/settings.py

# %%
# !head - n 22 tving_vod/tving_vod/settings.py | tail - n 2
# Out:
# # Obey robots.txt rules
# ROBOTSTXT_OBEY = False

# %%
# 파이프라인 열기
#ITEM_PIPELINES = {
#    'navertv.pipelines.NavertvPipeline': 300,
#}

# MySQL 설정
#CONNECTION_STRING = "{drivername}://{user}:{passwd}@{host}:{port}/{db_name}?charset=utf8mb4".format(
#     drivername="mysql",
#     user="root",
#     passwd="password",
#     host="**.***.**.***",
#     port="****",
#     db_name="OTT",
#)

# %% [markdown]
# ### run.sh

# %%
% % writefile tving_vod/run.sh
cd tving_vod
scrapy crawl TvingVod - o tving_vod_04.csv
# Out:
# Overwriting tving_vod/run.sh

# %%
# 권한 변경
import os
os.chmod("tving_vod/run.sh", 0o764)

# %%
# !ls - al tving_vod/run.sh
# Out:
# -rwxrw-r-- 1 ubuntu ubuntu 51 Apr  8 12:10 tving_vod/run.sh

# %% [markdown]
# ### 크롤링 실행하고 확인하기

# %%
# 크롤링 실행하고 확인하기

# !tving_vod/run.sh

df = pd.read_csv("./tving_vod/TvingVod.csv")
df.head()

# %%
# !tving_vod/run.sh
# Out:
# 2020-04-23 10:31:47 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: tving_vod)
# 2020-04-23 10:31:47 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.6.9 (default, Jan 17 2020, 08:43:56) - [GCC 7.4.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-1065-aws-x86_64-with-debian-buster-sid
# 2020-04-23 10:31:47 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'tving_vod', 'FEED_FORMAT': 'csv', 'FEED_URI': 'TvingVod_test.csv', 'NEWSPIDER_MODULE': 'tving_vod.spiders', 'SPIDER_MODULES': ['tving_vod.spiders']}
# 2020-04-23 10:31:47 [scrapy.extensions.telnet] INFO: Telnet Password: ba4b62da01c3b482
# 2020-04-23 10:31:47 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-04-23 10:31:47 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-04-23 10:31:47 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-04-23 10:31:47 [scrapy.middleware] INFO: Enabled item pipelines:
# ['tving_vod.pipelines.TvingVodPipeline']
# 2020-04-23 10:31:47 [scrapy.core.engine] INFO: Spider opened
# 2020-04-23 10:31:47 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-04-23 10:31:47 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-04-23 10:31:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.tving.com/vod/popular> (referer: None)
# 2020-04-23 10:31:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610> (referer: http://www.tving.com/vod/popular)
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': '채널A',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003040793',
#  'program': '하트시그널 시즌3',
#  'sale_day': 381,
#  'sale_week': 223,
#  'title': '하트시그널 시즌3 4화',
#  'view_day': 19601,
#  'view_week': 4192}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200418,
#  'channel': 'JTBC',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003039317',
#  'program': '부부의 세계',
#  'sale_day': 58,
#  'sale_week': 1330,
#  'title': '부부의 세계 8화',
#  'view_day': 15532,
#  'view_week': 186376}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': 'JTBC',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003038514',
#  'program': '날씨가 좋으면 찾아가겠어요',
#  'sale_day': 30,
#  'sale_week': 58,
#  'title': '날씨가 좋으면 찾아가겠어요 16화',
#  'view_day': 13140,
#  'view_week': 14994}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200416,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003031217',
#  'program': '슬기로운 의사생활',
#  'sale_day': 16,
#  'sale_week': 1164,
#  'title': '슬기로운 의사생활 6화',
#  'view_day': 12907,
#  'view_week': 246472}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': 'TV CHOSUN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003039048',
#  'program': '아내의 맛',
#  'sale_day': 17,
#  'sale_week': 24,
#  'title': '세상 어디에도 없는 ′아내의 맛′ 94화',
#  'view_day': 10490,
#  'view_week': 9945}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003037119',
#  'program': '메모리스트',
#  'sale_day': 21,
#  'sale_week': 14,
#  'title': '메모리스트 13화',
#  'view_day': 9659,
#  'view_week': 1971}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003036719',
#  'program': '유 퀴즈 온 더 블럭',
#  'sale_day': 45,
#  'sale_week': 35,
#  'title': '유 퀴즈 온 더 블럭 51화',
#  'view_day': 8712,
#  'view_week': 2567}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200418,
#  'channel': 'JTBC',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003033343',
#  'program': '아는 형님',
#  'sale_day': 4,
#  'sale_week': 46,
#  'title': '아는 형님 226화',
#  'view_day': 7977,
#  'view_week': 59197}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003037192',
#  'program': '반의반',
#  'sale_day': 21,
#  'sale_week': 52,
#  'title': '반의반 10화',
#  'view_day': 6048,
#  'view_week': 7266}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200420,
#  'channel': 'tvN',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E003036130',
#  'program': '요즘책방 : 책 읽어드립니다',
#  'sale_day': 10,
#  'sale_week': 35,
#  'title': '책 읽어드립니다 29화',
#  'view_day': 5502,
#  'view_week': 12200}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200419,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003034978',
#  'program': '하이바이, 마마!',
#  'sale_day': 13,
#  'sale_week': 209,
#  'title': '하이바이마마 16화',
#  'view_day': 5360,
#  'view_week': 45179}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200419,
#  'channel': 'JTBC',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E002545689',
#  'program': '뭉쳐야 찬다',
#  'sale_day': 21,
#  'sale_week': 153,
#  'title': '뭉쳐야 찬다 42화',
#  'view_day': 5318,
#  'view_week': 35222}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200411,
#  'channel': 'JTBC',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003032617',
#  'program': '[무삭제판] 부부의 세계',
#  'sale_day': 15,
#  'sale_week': 378,
#  'title': '[무삭제판] 부부의 세계 6화',
#  'view_day': 5167,
#  'view_week': 96299}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': 'KBS Joy',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003038565',
#  'program': '연애의 참견 시즌3',
#  'sale_day': 2,
#  'sale_week': 2,
#  'title': '연애의 참견 시즌3 16화',
#  'view_day': 4740,
#  'view_week': 3594}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200418,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003032209',
#  'program': '놀라운 토요일-도레미마켓',
#  'sale_day': 15,
#  'sale_week': 215,
#  'title': '도레미 마켓 104화',
#  'view_day': 4717,
#  'view_week': 51069}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200419,
#  'channel': 'OCN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003034050',
#  'program': '루갈',
#  'sale_day': 4,
#  'sale_week': 34,
#  'title': '루갈 8화',
#  'view_day': 3270,
#  'view_week': 19629}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200420,
#  'channel': 'JTBC',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003038568',
#  'program': '77억의 사랑',
#  'sale_day': 5,
#  'sale_week': 32,
#  'title': '77억의 사랑 11화',
#  'view_day': 2876,
#  'view_week': 8670}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200405,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003020957',
#  'program': '대탈출 3',
#  'sale_day': 17,
#  'sale_week': 185,
#  'title': '대탈출3 6화',
#  'view_day': 2875,
#  'view_week': 26978}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': 'JTBC',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003038569',
#  'program': '돈길만 걸어요 - 정산회담',
#  'sale_day': 3,
#  'sale_week': 3,
#  'title': '돈길만 걸어요 - 정산회담 11화',
#  'view_day': 2231,
#  'view_week': 2136}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': 'KBS Joy',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003038563',
#  'program': '무엇이든 물어보살',
#  'sale_day': 2,
#  'sale_week': 3,
#  'title': '무엇이든 물어보살 57화',
#  'view_day': 1979,
#  'view_week': 3432}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200419,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003038421',
#  'program': '코미디빅리그',
#  'sale_day': 5,
#  'sale_week': 23,
#  'title': '코미디빅리그 356화',
#  'view_day': 1780,
#  'view_week': 9397}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200417,
#  'channel': 'IHQ',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003036631',
#  'program': '맛있는 녀석들',
#  'sale_day': 1,
#  'sale_week': 16,
#  'title': '맛있는 녀석들 269화',
#  'view_day': 1592,
#  'view_week': 17860}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003037117',
#  'program': '수미네 반찬',
#  'sale_day': 1,
#  'sale_week': 3,
#  'title': '수미네반찬 98화',
#  'view_day': 1552,
#  'view_week': 1496}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200417,
#  'channel': 'JTBC',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003033109',
#  'program': '팬텀싱어 3',
#  'sale_day': 3,
#  'sale_week': 92,
#  'title': '팬텀싱어시즌3 2화',
#  'view_day': 1446,
#  'view_week': 19582}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200420,
#  'channel': 'XtvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E002380770',
#  'program': '프리한19',
#  'sale_day': 2,
#  'sale_week': 3,
#  'title': '인생을 뒤바꾼 역사적 그날 19',
#  'view_day': 1310,
#  'view_week': 3214}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200412,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003031519',
#  'program': '대탈출3 명장면 TOP 50',
#  'sale_day': 1,
#  'sale_week': 49,
#  'title': '대탈출3 명장면 TOP 50 1화',
#  'view_day': 1164,
#  'view_week': 15220}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200418,
#  'channel': 'JTBC',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003034052',
#  'program': '트래블러 - 아르헨티나',
#  'sale_day': 3,
#  'sale_week': 27,
#  'title': '트래블러-아르헨티나 10화',
#  'view_day': 1138,
#  'view_week': 9470}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200419,
#  'channel': 'JTBC',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003034171',
#  'program': '방구석1열',
#  'sale_day': 1,
#  'sale_week': 9,
#  'title': '방구석 1열 102화',
#  'view_day': 1082,
#  'view_week': 8252}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20190602,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E002349424',
#  'program': '대탈출 2',
#  'sale_day': 6,
#  'sale_week': 45,
#  'title': '대탈출2 12화',
#  'view_day': 1076,
#  'view_week': 8569}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'JTBC',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E002667420',
#  'program': '차이나는 클라스 - 질문 있습니다',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '차이나는 클라스 153화',
#  'view_day': 960,
#  'view_week': 299}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200416,
#  'channel': 'Olive',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003016906',
#  'program': '편 먹고 갈래요? <밥블레스유 2>',
#  'sale_day': 1,
#  'sale_week': 44,
#  'title': '밥블레스유2 5화',
#  'view_day': 928,
#  'view_week': 14737}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'JTBC',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E002963921',
#  'program': 'JTBC 뉴스룸',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': 'JTBC 뉴스룸',
#  'view_day': 889,
#  'view_week': 5736}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': 'MBC every1',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003041651',
#  'program': '비디오스타',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '<비디오 스타> 193화',
#  'view_day': 876,
#  'view_week': 923}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200416,
#  'channel': 'TV CHOSUN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003033504',
#  'program': '신청곡을 불러드립니다-사랑의 콜센타',
#  'sale_day': 1,
#  'sale_week': 43,
#  'title': '신청곡을 불러드립니다-사랑의 콜센타 3화',
#  'view_day': 861,
#  'view_week': 14643}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200216,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E002961018',
#  'program': '사랑의 불시착',
#  'sale_day': 1,
#  'sale_week': 20,
#  'title': '사랑의 불시착 16화',
#  'view_day': 805,
#  'view_week': 5529}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20190609,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E002367622',
#  'program': '대탈출2 감독판',
#  'sale_day': 1,
#  'sale_week': 2,
#  'title': '대탈출2 감독판 1화',
#  'view_day': 744,
#  'view_week': 5552}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200321,
#  'channel': 'JTBC',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003005608',
#  'program': '이태원 클라쓰',
#  'sale_day': 3,
#  'sale_week': 15,
#  'title': '이태원 클라쓰 16화',
#  'view_day': 687,
#  'view_week': 5661}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20180924,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E001781416',
#  'program': '대탈출',
#  'sale_day': 2,
#  'sale_week': 9,
#  'title': '대탈출 13화',
#  'view_day': 681,
#  'view_week': 5011}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200103,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E002883330',
#  'program': '신서유기 7',
#  'sale_day': 1,
#  'sale_week': 3,
#  'title': '신서유기7 11화',
#  'view_day': 622,
#  'view_week': 3821}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'MBN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003038845',
#  'program': '우리 다시 사랑할 수 있을까 시즌2',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '우리 다시 사랑할 수 있을까 시즌2 6화',
#  'view_day': 620,
#  'view_week': 120}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200417,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003038570',
#  'program': '마포 멋쟁이',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '마포 멋쟁이 7화',
#  'view_day': 620,
#  'view_week': 7474}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200419,
#  'channel': 'JTBC',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003034163',
#  'program': '스타와 직거래-유랑마켓',
#  'sale_day': 1,
#  'sale_week': 39,
#  'title': '유랑마켓 10화',
#  'view_day': 612,
#  'view_week': 4417}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20180118,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E001316300',
#  'program': '슬기로운 감빵생활',
#  'sale_day': 1,
#  'sale_week': 3,
#  'title': '슬기로운 감빵생활 16화',
#  'view_day': 602,
#  'view_week': 3841}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': '채널A',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E003039983',
#  'program': '천일야史',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '천일야사 174화',
#  'view_day': 599,
#  'view_week': 550}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200418,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003036318',
#  'program': '더블 캐스팅',
#  'sale_day': 3,
#  'sale_week': 68,
#  'title': '더블캐스팅 9화',
#  'view_day': 541,
#  'view_week': 6544}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200418,
#  'channel': '채널A',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003036137',
#  'program': '유별나! 문셰프',
#  'sale_day': 1,
#  'sale_week': 3,
#  'title': '유별나 문셰프 8화',
#  'view_day': 540,
#  'view_week': 5070}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20190802,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E002504819',
#  'program': '신서유기 외전 강식당 3',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '강식당3 4화',
#  'view_day': 486,
#  'view_week': 2561}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200417,
#  'channel': 'tvN',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E003032941',
#  'program': '김창옥 쇼',
#  'sale_day': 3,
#  'sale_week': 90,
#  'title': '김창옥 쇼 1화',
#  'view_day': 475,
#  'view_week': 6153}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'MBC every1',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003043119',
#  'program': '주간 아이돌',
#  'sale_day': 7,
#  'sale_week': 3,
#  'title': '주간아이돌 456화',
#  'view_day': 456,
#  'view_week': 329}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20190705,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E002435077',
#  'program': '신서유기 외전 강식당 2',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '강식당2 6화',
#  'view_day': 456,
#  'view_week': 2524}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20181028,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E001860567',
#  'program': '신서유기 5',
#  'sale_day': 2,
#  'sale_week': 3,
#  'title': '신서유기5 5화',
#  'view_day': 453,
#  'view_week': 2805}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20171116,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E001261415',
#  'program': '부암동 복수자들',
#  'sale_day': 4,
#  'sale_week': 5,
#  'title': '부암동 복수자들 12화',
#  'view_day': 441,
#  'view_week': 954}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200419,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003034979',
#  'program': '캐시백',
#  'sale_day': 2,
#  'sale_week': 9,
#  'title': '캐시백 1화',
#  'view_day': 411,
#  'view_week': 2983}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200416,
#  'channel': '투니버스',
#  'genre': '키즈/애니',
#  'p_url': 'http://www.tving.com/vod/player/E003019899',
#  'program': '신비아파트 고스트볼 더블X 6개의 예언',
#  'sale_day': 3,
#  'sale_week': 216,
#  'title': '7화  나태지옥의 비명, 공포의 휘파람 소리',
#  'view_day': 395,
#  'view_week': 4545}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20181202,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E001941421',
#  'program': '신서유기 6',
#  'sale_day': 1,
#  'sale_week': 2,
#  'title': '신서유기6 5화',
#  'view_day': 390,
#  'view_week': 2307}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'Mnet',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003037017',
#  'program': 'TMI NEWS',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': 'TMI NEWS 38화 정세운&서지음',
#  'view_day': 322,
#  'view_week': 179}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20170815,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E001231481',
#  'program': '신서유기 4',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '신서유기 시즌4 10화',
#  'view_day': 319,
#  'view_week': 1707}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20190901,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E002579135',
#  'program': '호텔 델루나',
#  'sale_day': 1,
#  'sale_week': 2,
#  'title': '호텔 델루나 16화',
#  'view_day': 310,
#  'view_week': 1857}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': 'Mnet',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003035518',
#  'program': '퀴즈와 음악사이',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '퀴즈와 음악사이 4화',
#  'view_day': 303,
#  'view_week': 452}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200412,
#  'channel': 'OCN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003031520',
#  'program': '루갈 무삭제판',
#  'sale_day': 2,
#  'sale_week': 10,
#  'title': '루갈 무삭제판 6화',
#  'view_day': 303,
#  'view_week': 5855}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20190725,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E002489443',
#  'program': '검색어를 입력하세요 WWW',
#  'sale_day': 1,
#  'sale_week': 4,
#  'title': '검색어를 입력하세요 WWW 16화',
#  'view_day': 297,
#  'view_week': 1757}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200409,
#  'channel': '채널A',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003028571',
#  'program': '나만 믿고 따라와, 도시어부2',
#  'sale_day': 1,
#  'sale_week': 2,
#  'title': '도시어부2 : 대항해 시대 17화',
#  'view_day': 285,
#  'view_week': 3988}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200326,
#  'channel': 'TV CHOSUN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003012926',
#  'program': '미스터트롯의 맛',
#  'sale_day': 1,
#  'sale_week': 2,
#  'title': '미스터트롯의 맛 2화',
#  'view_day': 285,
#  'view_week': 1867}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200420,
#  'channel': '채널A',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003039981',
#  'program': '풍문으로 들었쇼',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '풍문으로 들었쇼 236화',
#  'view_day': 275,
#  'view_week': 1109}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20190928,
#  'channel': 'JTBC',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E002650613',
#  'program': '멜로가 체질',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '멜로가 체질 16화',
#  'view_day': 268,
#  'view_week': 1813}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20191213,
#  'channel': '투니버스',
#  'genre': '키즈/애니',
#  'p_url': 'http://www.tving.com/vod/player/E002837736',
#  'program': '명탐정코난17',
#  'sale_day': 1,
#  'sale_week': 4,
#  'title': '37화  닮은 사람끼리 견원지간',
#  'view_day': 264,
#  'view_week': 2009}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'TV CHOSUN',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E003036018',
#  'program': '인생다큐 마이웨이',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '인생다큐 마이웨이 194화',
#  'view_day': 262,
#  'view_week': 75}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200419,
#  'channel': 'MBN',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E003039721',
#  'program': '기막힌 이야기 - 실제상황',
#  'sale_day': 1,
#  'sale_week': 4,
#  'title': '기막힌 이야기 실제상황 387화',
#  'view_day': 254,
#  'view_week': 1118}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20170822,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E001234643',
#  'program': '신서유기 4 감독판',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '신서유기_시즌4_감독판',
#  'view_day': 254,
#  'view_week': 1539}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200416,
#  'channel': 'MBC every1',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003036417',
#  'program': '어서와~ 한국은 처음이지?',
#  'sale_day': 1,
#  'sale_week': 9,
#  'title': '[어서와 한국은 처음이지?] 135화',
#  'view_day': 247,
#  'view_week': 4972}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'skyDrama',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003043937',
#  'program': '막후지왕 : 러브 온 에어',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '막후지왕 : 러브 온 에어 1화',
#  'view_day': 243,
#  'view_week': 43}
# 2020-04-23 10:31:48 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20191111,
#  'channel': '투니버스',
#  'genre': '키즈/애니',
#  'p_url': 'http://www.tving.com/vod/player/E002761119',
#  'program': '짱구는못말려19',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '제24화 감기에 걸려서 심심해요/아빠가 건강검진을 받는대요/아기 타조의 엄마가 됐어요',
#  'view_day': 243,
#  'view_week': 1795}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200420,
#  'channel': 'MBN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003037498',
#  'program': '오지GO 아마존 of 아마존',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '오지GO 아마존 of 아마존 1화',
#  'view_day': 241,
#  'view_week': 1062}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200417,
#  'channel': 'Mnet',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003032742',
#  'program': '내 안의 발라드',
#  'sale_day': 1,
#  'sale_week': 7,
#  'title': '내 안의 발라드 9화',
#  'view_day': 240,
#  'view_week': 3093}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'MBC every1',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003043118',
#  'program': '대한외국인',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '대한외국인 80화',
#  'view_day': 239,
#  'view_week': 94}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'CH.DIA',
#  'genre': '디지털오리지널',
#  'p_url': 'http://www.tving.com/vod/player/E003042218',
#  'program': '입짧은햇님',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '입짧은햇님 104화',
#  'view_day': 230,
#  'view_week': 169}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'Olive',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003036720',
#  'program': '프리한마켓10',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '프리한 마켓 10 25화',
#  'view_day': 227,
#  'view_week': 122}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20170121,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E001165756',
#  'program': '도깨비',
#  'sale_day': 1,
#  'sale_week': 3,
#  'title': '도깨비 16화',
#  'view_day': 226,
#  'view_week': 1304}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200420,
#  'channel': 'MBN',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E003038851',
#  'program': '판도라',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '판도라 166화',
#  'view_day': 218,
#  'view_week': 751}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20180805,
#  'channel': 'OCN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E001677738',
#  'program': '라이프 온 마스',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '라이프온마스 16화',
#  'view_day': 215,
#  'view_week': 1361}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'JTBC',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E002963922',
#  'program': '정치부 회의',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '정치부 회의',
#  'view_day': 203,
#  'view_week': 968}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200322,
#  'channel': 'OCN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003006327',
#  'program': '본 대로 말하라',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '본대로말하라 16화',
#  'view_day': 201,
#  'view_week': 1275}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20160116,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E000971617',
#  'program': '응답하라 1988',
#  'sale_day': 1,
#  'sale_week': 2,
#  'title': '응답하라1988 20화',
#  'view_day': 197,
#  'view_week': 1266}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20151211,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E000950906',
#  'program': '삼시세끼 어촌편 2',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '삼시세끼 어촌편2 10화',
#  'view_day': 195,
#  'view_week': 757}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'skyDrama',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003038117',
#  'program': '장야 시즌2',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '장야2 17화',
#  'view_day': 189,
#  'view_week': 23}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20170317,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E001183701',
#  'program': '신서유기 3',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '신서유기 시즌3 스페셜',
#  'view_day': 186,
#  'view_week': 1094}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200306,
#  'channel': 'JTBC',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E002987600',
#  'program': '투유 프로젝트 - 슈가맨 3',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '슈가맨 3 14화',
#  'view_day': 182,
#  'view_week': 1030}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20171128,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E001260560',
#  'program': '신서유기외전 - 꽃보다 청춘 위너',
#  'sale_day': 1,
#  'sale_week': 5,
#  'title': '신서유기 외전(꽃보다위너) 4화',
#  'view_day': 182,
#  'view_week': 669}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200317,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E003004157',
#  'program': '방법',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '방법 12화',
#  'view_day': 181,
#  'view_week': 1675}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20191127,
#  'channel': 'tvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E002809717',
#  'program': '신서유기 외전: 아이슬란드 간 세끼 60분 특별판',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '신서유기 외전  아이슬란드 간 세끼 60분 특별판',
#  'view_day': 178,
#  'view_week': 1060}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200321,
#  'channel': 'XtvN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003005521',
#  'program': '플레이어 2',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '플레이어2 8화',
#  'view_day': 173,
#  'view_week': 1332}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200403,
#  'channel': 'Mnet',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003018766',
#  'program': '너의 목소리가 보여 7',
#  'sale_day': 1,
#  'sale_week': 2,
#  'title': '너의 목소리가 보여7 12화',
#  'view_day': 168,
#  'view_week': 1600}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200421,
#  'channel': '채널W',
#  'genre': '해외시리즈',
#  'p_url': 'http://www.tving.com/vod/player/E003043120',
#  'program': '불모지대',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '불모지대 12화',
#  'view_day': 167,
#  'view_week': 223}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20180517,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E001518893',
#  'program': '나의 아저씨',
#  'sale_day': 1,
#  'sale_week': 5,
#  'title': '나의 아저씨 16화',
#  'view_day': 166,
#  'view_week': 1001}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20131228,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E000568449',
#  'program': '응답하라 1994',
#  'sale_day': 1,
#  'sale_week': 4,
#  'title': '90년대에게',
#  'view_day': 163,
#  'view_week': 704}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20181120,
#  'channel': 'JTBC',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E001916362',
#  'program': '뷰티 인사이드',
#  'sale_day': 1,
#  'sale_week': 1,
#  'title': '뷰티 인사이드 16화',
#  'view_day': 162,
#  'view_week': 713}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'JTBC',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E002963923',
#  'program': '사건반장',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '사건반장',
#  'view_day': 160,
#  'view_week': 914}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20180506,
#  'channel': 'tvN',
#  'genre': '드라마',
#  'p_url': 'http://www.tving.com/vod/player/E001492798',
#  'program': '라이브(Live)',
#  'sale_day': 1,
#  'sale_week': 4,
#  'title': '라이브 18화',
#  'view_day': 155,
#  'view_week': 1047}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200422,
#  'channel': 'MBN',
#  'genre': '교양',
#  'p_url': 'http://www.tving.com/vod/player/E003038849',
#  'program': '나는 자연인이다',
#  'sale_day': 0,
#  'sale_week': 0,
#  'title': '나는 자연인이다 396화',
#  'view_day': 154,
#  'view_week': 59}
# 2020-04-23 10:31:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://api.tving.com/v2/media/episodes?pageNo=1&pageSize=100&order=viewDay&adult=all&free=all&guest=all&scope=all&lastFrequency=y&personal=N&screenCode=CSSD0100&networkCode=CSND0900&osCode=CSOD0900&teleCode=CSCD0900&apiKey=1e7952d0917d6aab1f0293a063697610>
# {'broadcast_date': 20200314,
#  'channel': 'TV CHOSUN',
#  'genre': '예능',
#  'p_url': 'http://www.tving.com/vod/player/E003004180',
#  'program': '미스터트롯',
#  'sale_day': 1,
#  'sale_week': 2,
#  'title': '내일은 미스터트롯 12화',
#  'view_day': 154,
#  'view_week': 1127}
# 2020-04-23 10:31:49 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-04-23 10:31:49 [scrapy.extensions.feedexport] INFO: Stored csv feed (100 items) in: TvingVod_test.csv
# 2020-04-23 10:31:49 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 712,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 127328,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 1.475689,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 4, 23, 1, 31, 49, 293419),
#  'item_scraped_count': 100,
#  'log_count/DEBUG': 102,
#  'log_count/INFO': 11,
#  'memusage/max': 66383872,
#  'memusage/startup': 66383872,
#  'request_depth_max': 1,
#  'response_received_count': 2,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2020, 4, 23, 1, 31, 47, 817730)}
# 2020-04-23 10:31:49 [scrapy.core.engine] INFO: Spider closed (finished)
