# %%
from IPython.display import Image

# %%
Image("티빙_스크래피/스크래피_스파이더.PNG")

# %%
Image("티빙_스크래피/스크래피_저장.PNG")

# %%
Image("티빙_스크래피/스크래피_데이터프레임.PNG")

# %%
Image("티빙_스크래피/스크래피_파이프라인연결.PNG")

# %%
Image("티빙_스크래피/스크래피_파이프라인연결2.PNG")

# %%
Image("티빙_스크래피/스크래피_파이프라인연결3.PNG")

# %%
Image("티빙_스크래피/몽고디비.PNG")
