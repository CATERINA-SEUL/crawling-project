# %% [markdown]
# ### 네이버TV 크롤링

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
def navertv():
    response = requests.get('https://tv.naver.com/r/')
    dom = BeautifulSoup(response.content, 'html.parser')
    top3 = dom.select('#container > div > div.top_main > div > div > div > ul > li')
    top100 = dom.select('#content > div > div > div > div')
    
    # top3
    datas = []
    for top in top3:
        datas.append({
            "title": top.select_one('[class="title"]').text.replace('\n', ''),
            "program": top.select_one('[class="ch"]').text,
            "count": top.select_one('[class="hit"]').text.replace('재생 수', ''),
            "like": top.select_one('[class="like"]').text.replace('좋아요 수', ''),
            "link": top.find('a').get('href')
            })
    top3_df = pd.DataFrame(datas, columns=['title', 'program', 'count', 'like', 'link'])
    
    #top100
    datas2 = []
    for top in top100:
        datas2.append({
            "title": top.select_one('tooltip').text,
            "program": top.select_one('.chn').text.strip(),
            "count": top.select_one('[class="hit"]').text.replace('재생 수', ''),
            "like": top.select_one('[class="like"]').text.replace('좋아요 수', ''),
            "link": top.find('a').get('href')
            })
    top100_df = pd.DataFrame(datas2, columns=['title', 'program', 'count', 'like', 'link'])

    return pd.concat([top3_df, top100_df]).reset_index(drop=True)

# %%
df = navertv()
df.iloc[:5]
# Out:
#                                     title   program      count    like  \
# 0             [찐한 엔딩] 김혜수♡주지훈, 격정적인 KISS♥      하이에나    674,987   6,002
# 1      [선공개] 이상윤·육성재, 눈물과 함께한 집사부일체와의 마지막     집사부일체     92,453     630
# 2  [선공개] 홍진영, ‘트롯퀸’ 김연자 드레스 보고 반짝이 의상 홀릭!  미운 우리 새끼     67,006     221
# 3            ☞눈물주의☜ 임영웅 ‘배신자’♭ 얄밉게 떠난 님아☹     미스터트롯  1,653,334  19,802
# 4            [충격 엔딩] 나는… 네가 지금 미치도록 보고 싶다   이태원 클라쓰    444,051   3,715
#
#                                          link
# 0  https://tv.naver.com/v/12870385/list/67096
# 1  https://tv.naver.com/v/12873342/list/67096
# 2  https://tv.naver.com/v/12867654/list/67096
# 3  https://tv.naver.com/v/12840075/list/67096
# 4  https://tv.naver.com/v/12869932/list/67096

# %% [markdown]
# # Scrapy로 크롤링한 데이터 Mongodb에 저장하기

# %% [markdown]
# ### 1. 프로젝트 생성

# %%
# !scrapy startproject navertv
# Out:
# New Scrapy project 'navertv', using template directory '/home/ubuntu/.pyenv/versions/3.6.9/envs/python3/lib/python3.6/site-packages/scrapy/templates/project', created in:
#     /home/ubuntu/notebook/크롤링프로젝트/navertv
#
# You can start your first spider with:
#     cd navertv
#     scrapy genspider example example.com

# %%
# !tree navertv
# Out:
# navertv
# ├── navertv
# │   ├── __init__.py
# │   ├── __pycache__
# │   ├── items.py
# │   ├── middlewares.py
# │   ├── pipelines.py
# │   ├── settings.py
# │   └── spiders
# │       ├── __init__.py
# │       └── __pycache__
# └── scrapy.cfg
#
# 4 directories, 7 files

# %% [markdown]
# ### 2. itmes.py 수정

# %%
! cat navertv/navertv/items.py
# Out:
# # -*- coding: utf-8 -*-
#
# # Define here the models for your scraped items
# #
# # See documentation in:
# # https://docs.scrapy.org/en/latest/topics/items.html
#
# import scrapy
#
#
# class NavertvItem(scrapy.Item):
#     # define the fields for your item here like:
#     # name = scrapy.Field()
#     pass

# %%
# %%writefile navertv/navertv/items.py
import scrapy

class NavertvItem(scrapy.Item):
    title = scrapy.Field()
    program = scrapy.Field()
    count = scrapy.Field()
    like = scrapy.Field()
    link = scrapy.Field()
# Out:
# Overwriting navertv/navertv/items.py

# %% [markdown]
# ### 3. spider.py 생성

# %%
# %%writefile navertv/navertv/spiders/spider.py
import scrapy
from bs4 import BeautifulSoup

from navertv.items import NavertvItem

class spider(scrapy.Spider):
    
    name = "Navertv"
    allow_domain = ['tv.naver.com']
    #start_urls = ['https://tv.naver.com/r/']
    
    def start_requests(self):
        urls = 'https://tv.naver.com/r/'
        yield scrapy.Request(url=urls, callback=self.top3_content)
        
    def top3_content(self, response):
        dom = BeautifulSoup(response.body, 'html.parser')
        top3 = dom.select('#container > div > div.top_main > div > div > div > ul > li')
        top100 = dom.select('#content > div > div > div > div')
        
        for top in top3:
            title = top.select_one('[class="title"]').text.replace('\n', '')
            program = top.select_one('[class="ch"]').text
            count = top.select_one('[class="hit"]').text.replace('재생 수', '')
            like = top.select_one('[class="like"]').text.replace('좋아요 수', '')
            link = top.find('a').get('href')
                
            item = NavertvItem()
            item['title'] = title
            item['program'] = program
            item['count'] = count
            item['like'] = like
            item['link'] = link
            
            yield item
    
        for top in top100:
            title = top.select_one('tooltip').text
            program = top.select_one('.chn').text.strip()
            count = top.select_one('[class="hit"]').text.replace('재생 수', '')
            like = top.select_one('[class="like"]').text.replace('좋아요 수', '')
            link = top.find('a').get('href')
        
            item = NavertvItem()
            item['title'] = title
            item['program'] = program
            item['count'] = count
            item['like'] = like
            item['link'] = link
    
            yield item
# Out:
# Overwriting navertv/navertv/spiders/spider.py

# %%
# %%writefile navertv/run.sh
# cd navertv
# #PATH = /home/ubuntu/.pyenv/versions/3.6.9/envs/python3/lib/python3.6/site-packages
# #export PATH
# scrapy crawl Navertv -o items.csv
# Out:
# Overwriting navertv/run.sh

# %%
# !ls -al run.sh
# Out:
# -rw-rw-r-- 1 ubuntu ubuntu 45 Mar 15 14:32 run.sh

# %%
import os
os.chmod("run.sh", 0o764)

# %%
# !ls -al run.sh
# Out:
# -rwxrw-r-- 1 ubuntu ubuntu 45 Mar 15 14:32 run.sh

# %%
! navertv/run.sh
# Out:
# navertv/run.sh: 2: navertv/run.sh: PATH: not found
# 2020-03-15 22:08:12 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: navertv)
# 2020-03-15 22:08:12 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.6.9 (default, Jan 17 2020, 08:43:56) - [GCC 7.4.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-1060-aws-x86_64-with-debian-buster-sid
# 2020-03-15 22:08:12 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'navertv', 'FEED_FORMAT': 'csv', 'FEED_URI': 'items.csv', 'NEWSPIDER_MODULE': 'navertv.spiders', 'SPIDER_MODULES': ['navertv.spiders']}
# 2020-03-15 22:08:12 [scrapy.extensions.telnet] INFO: Telnet Password: 58c4bf00e2dd06ce
# 2020-03-15 22:08:12 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-03-15 22:08:12 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-03-15 22:08:12 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-03-15 22:08:13 [scrapy.middleware] INFO: Enabled item pipelines:
# ['navertv.pipelines.NavertvPipeline']
# 2020-03-15 22:08:13 [scrapy.core.engine] INFO: Spider opened
# 2020-03-15 22:08:13 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-03-15 22:08:13 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-03-15 22:08:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://tv.naver.com/r/> (referer: None)
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '84,439',
#  'like': '516',
#  'link': 'https://tv.naver.com/v/12879070/list/67096',
#  'program': '런닝맨',
#  'title': '“세찬아!” 전소민, 양세찬에 박력 포옹☆ (ft. 지석진 방X)'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '35,959',
#  'like': '1,925',
#  'link': 'https://tv.naver.com/v/12880188/list/67096',
#  'program': '복면가왕',
#  'title': "'주윤발' 의 가왕 방어전 무대 - 멀어지다\r"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '480,782',
#  'like': '6,250',
#  'link': 'https://tv.naver.com/v/12870388/list/67096',
#  'program': '미스터트롯',
#  'title': '♛진(眞)·선(善)♛ ‘영웅이냐 영탁이냐’ 진은 임.영.웅'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,703,548',
#  'like': '20,004',
#  'link': 'https://tv.naver.com/v/12840075/list/67096',
#  'program': '미스터트롯',
#  'title': '☞눈물주의☜ 임영웅 ‘배신자’♭ 얄밉게 떠난 님아☹'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '869,651',
#  'like': '7,088',
#  'link': 'https://tv.naver.com/v/12870385/list/67096',
#  'program': '하이에나',
#  'title': '[찐한 엔딩] 김혜수♡주지훈, 격정적인 KISS♥'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '319,653',
#  'like': '5,103',
#  'link': 'https://tv.naver.com/v/12624975/list/67096',
#  'program': '복면가왕',
#  'title': "'주윤발' 3라운드 무대 - 가족사진"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '37,397',
#  'like': '1,093',
#  'link': 'https://tv.naver.com/v/12878027/list/67096',
#  'program': 'SBS 인기가요',
#  'title': '대세 걸그룹 ‘있지’의 파워풀 에너지★ ‘WANNABE’'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '36,285',
#  'like': '153',
#  'link': 'https://tv.naver.com/v/12878999/list/67096',
#  'program': '런닝맨',
#  'title': '‘제가 뀌었습니다!?’ 전소민×지석진, 방귀 범인은 누구?'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '242,980',
#  'like': '2,562',
#  'link': 'https://tv.naver.com/v/12869765/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '박서준, 연적 김동희를 향한 선포 ＂내가 다미 좋아한다-＂'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '63,352',
#  'like': '2,990',
#  'link': 'https://tv.naver.com/v/12866190/list/67096',
#  'program': '쇼! 음악중심',
#  'title': 'NCT 127 -영웅(英雄), (NCT 127 -Kick It)'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '24,041',
#  'like': '291',
#  'link': 'https://tv.naver.com/v/12880601/list/67096',
#  'program': '집사부일체',
#  'title': '‘성재의 코골이가 그리울 거 같아요’ 이상윤, 마지막 인사에 눈물바다'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '972,949',
#  'like': '16,900',
#  'link': 'https://tv.naver.com/v/12839921/list/67096',
#  'program': '미스터트롯',
#  'title': '순이밖에 모르는 찬또..♡ 이찬원 ‘18세 순이’♪'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '41,554',
#  'like': '23',
#  'link': 'https://tv.naver.com/v/12880872/list/67096',
#  'program': 'JTBC뉴스',
#  'title': "1개 주 빼고 미 전역 '감염'…생필품 사재기 행렬 극심"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '21,201',
#  'like': '20',
#  'link': 'https://tv.naver.com/v/12879718/list/67096',
#  'program': 'JTBC뉴스',
#  'title': '프랑스 "전국 모든 상점 폐쇄"…스페인선 \'외출 금지령\''}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '9,566',
#  'like': '1,428',
#  'link': 'https://tv.naver.com/v/12878031/list/67096',
#  'program': 'SBS 인기가요',
#  'title': '‘빅톤’의 끊을 수 없는 집착! ‘Howling’'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '27,629',
#  'like': '32',
#  'link': 'https://tv.naver.com/v/12879044/list/67096',
#  'program': 'JTBC뉴스',
#  'title': 'CNN "미국인 일상생활 거의 마비"…유럽은 전국에 봉쇄령'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '573,414',
#  'like': '12,191',
#  'link': 'https://tv.naver.com/v/12839035/list/67096',
#  'program': '미스터트롯',
#  'title': '✦탁마에의 탄생✧ 엄지 척乃 영탁 ‘찐이야’♬'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '498,757',
#  'like': '7,921',
#  'link': 'https://tv.naver.com/v/12839270/list/67096',
#  'program': '미스터트롯',
#  'title': '✪주먹 장인✪ 임히어로 출격↗ 임영웅 ‘두 주먹’♩'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '24,418',
#  'like': '237',
#  'link': 'https://tv.naver.com/v/12878218/list/67096',
#  'program': '런닝맨',
#  'title': '양세찬×전소민, 동반 CF 촬영에 김종국 발끈♨ (ft. 야이 등신대)'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '511,269',
#  'like': '4,179',
#  'link': 'https://tv.naver.com/v/12869932/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '[충격 엔딩] 나는… 네가 지금 미치도록 보고 싶다'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '174,413',
#  'like': '2,522',
#  'link': 'https://tv.naver.com/v/12870179/list/67096',
#  'program': '하이에나',
#  'title': '“보고 싶어 왔다… 배알도 없이” 주지훈, 김혜수에 취중 고백♥'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '223,132',
#  'like': '4,262',
#  'link': 'https://tv.naver.com/v/12624568/list/67096',
#  'program': '복면가왕',
#  'title': "'주윤발' 2라운드 무대 - Who Are You"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '20,227',
#  'like': '20',
#  'link': 'https://tv.naver.com/v/12880621/list/67096',
#  'program': 'JTBC뉴스',
#  'title': '신규 확진 23일 만에 두 자릿수로…정부 "방심은 금물"'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '458,243',
#  'like': '7,294',
#  'link': 'https://tv.naver.com/v/12839883/list/67096',
#  'program': '미스터트롯',
#  'title': '음악에 대한 갈망.. 영탁 ‘내 삶의 이유있음은’♫'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '381,306',
#  'like': '4,061',
#  'link': 'https://tv.naver.com/v/12869650/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '김다미를 향한 마음을 깨달은 박서준 「온통 너다…」'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '19,201',
#  'like': '303',
#  'link': 'https://tv.naver.com/v/12880735/list/67096',
#  'program': '집사부일체',
#  'title': '이상윤＆육성재, 우리들에게 전하는 굿바이 인사'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '22,837',
#  'like': '773',
#  'link': 'https://tv.naver.com/v/12879419/list/67096',
#  'program': '런닝맨',
#  'title': '[3월 22일 예고] 광수 is Back! 기린의 귀환!'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '436,999',
#  'like': '7,159',
#  'link': 'https://tv.naver.com/v/12838898/list/67096',
#  'program': '미스터트롯',
#  'title': '14살에 깨우친 인생..✰ 정동원 ‘여백’♪'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '9,476',
#  'like': '244',
#  'link': 'https://tv.naver.com/v/12879839/list/67096',
#  'program': '집사부일체',
#  'title': '이상윤×육성재, 집사부일체 졸업에 터놓은 속마음'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '408,408',
#  'like': '10,814',
#  'link': 'https://tv.naver.com/v/12839699/list/67096',
#  'program': '미스터트롯',
#  'title': '트바로티 인생곡! 은사님께 드리는 노래... ‘고맙소’♩'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '13,905',
#  'like': '42',
#  'link': 'https://tv.naver.com/v/12881131/list/67096',
#  'program': 'MBC뉴스',
#  'title': '길게 늘어선 \'드라이브 스루\'…"한국 방식 배워야"'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '6,782',
#  'like': '365',
#  'link': 'https://tv.naver.com/v/12879898/list/67096',
#  'program': '집사부일체',
#  'title': '“질투 나요” 육성재, 마지막 밤! 아쉬운 마음에 솔직 폭발하는 막내'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '17,395',
#  'like': '179',
#  'link': 'https://tv.naver.com/v/12879192/list/67096',
#  'program': '런닝맨',
#  'title': '지석진, 유재석에 선 전화한 이광수에 삐짐↗ (ft. 유산슬)'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '19,396',
#  'like': '1,443',
#  'link': 'https://tv.naver.com/v/12878214/list/67096',
#  'program': 'SBS 인기가요',
#  'title': '가요계 NEW 영웅 ‘NCT 127’의 폭발적인 스웨그! ‘영웅’'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '10,891',
#  'like': '346',
#  'link': 'https://tv.naver.com/v/12879387/list/67096',
#  'program': '복면가왕',
#  'title': "'호랑나비' 2라운드 무대 - 그대가 그대를"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '6,474',
#  'like': '335',
#  'link': 'https://tv.naver.com/v/12880190/list/67096',
#  'program': '집사부일체',
#  'title': '※과잉 감동 방지※ 육성재, 끝까지 할 몫 다하는 집사부 막내☆'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '11,224',
#  'like': '1,024',
#  'link': 'https://tv.naver.com/v/12880710/list/67096',
#  'program': '집사부일체',
#  'title': '[3월 22일 예고] 실로 엄청난 적흥(?)력 옹성우의 반란!'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '123,874',
#  'like': '3,525',
#  'link': 'https://tv.naver.com/v/12870387/list/67096',
#  'program': '미스터트롯',
#  'title': "✿미(美)✿ '찬또배기' 이찬원의 진심 어린 수상 소감☺"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '7,145',
#  'like': '268',
#  'link': 'https://tv.naver.com/v/12879942/list/67096',
#  'program': '복면가왕',
#  'title': "'호랑나비' 3라운드 무대 - Sofa"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '35,376',
#  'like': '90',
#  'link': 'https://tv.naver.com/v/12873305/list/67096',
#  'program': '달수네라이브',
#  'title': '손흥민과 경쟁, 공존 아니면 아예 리빌딩 [달수네 라이브]'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '6,784',
#  'like': '179',
#  'link': 'https://tv.naver.com/v/12880600/list/67096',
#  'program': '복면가왕',
#  'title': "여심을 저격하는 마성의 보이스 '호랑나비'의 정체는! 호피폴라의 아일"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '10,052',
#  'like': '114',
#  'link': 'https://tv.naver.com/v/12879625/list/67096',
#  'program': '집사부일체',
#  'title': '‘미라클’ 이세돌, AI보다 빠른 오마이걸 노래 맞히기!'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '299,770',
#  'like': '1,228',
#  'link': 'https://tv.naver.com/v/12870438/list/67096',
#  'program': '하이에나',
#  'title': '[3월 20일 예고] 주지훈, 연락 안 되는 김혜수에 질투!'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '189,279',
#  'like': '659',
#  'link': 'https://tv.naver.com/v/12861163/list/67096',
#  'program': 'Talk about K LEAGUE',
#  'title': '[13년전, 오늘] 뭉쳐야 찬다 감독님 어마어마했던 현역시절 (2007.03.14)'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '24,757',
#  'like': '48',
#  'link': 'https://tv.naver.com/v/12877109/list/67096',
#  'program': '연합뉴스TV',
#  'title': '한 발 뺀 IOC, 불안감 커지는 일본'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '189,940',
#  'like': '6,265',
#  'link': 'https://tv.naver.com/v/12866192/list/67096',
#  'program': '쇼! 음악중심',
#  'title': '양준일 + 리아 킴 -Dance With Me 아가씨 (Yang Joon Il + Lia Kim -Dance with '
#           'me Lady)'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '29,316',
#  'like': '46',
#  'link': 'https://tv.naver.com/v/12875728/list/67096',
#  'program': 'DKTV',
#  'title': '“류현진은 피칭 천재!” MLB 취재 경력 40년차 베테랑 기자의 고백! | DKTV'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '12,024',
#  'like': '98',
#  'link': 'https://tv.naver.com/v/12878276/list/67096',
#  'program': '런닝맨',
#  'title': '조병규, 해맑은 미소로 빙구美 폭발! (ft. 담지효 근황)'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '6,296',
#  'like': '91',
#  'link': 'https://tv.naver.com/v/12879947/list/67096',
#  'program': '집사부일체',
#  'title': '이상윤, 예능에 전례 없던 캐릭터 이상윤이 졸업하는 날'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '175,903',
#  'like': '1,531',
#  'link': 'https://tv.naver.com/v/12869416/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '김동희와 함께 있는 김다미에 혼란스러운 박서준'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '7,454',
#  'like': '6',
#  'link': 'https://tv.naver.com/v/12880759/list/67096',
#  'program': 'MBC뉴스',
#  'title': '"\'허경영\'을 부르면 예방"…강연료 때문에'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '9,880',
#  'like': '6',
#  'link': 'https://tv.naver.com/v/12880518/list/67096',
#  'program': 'JTBC뉴스',
#  'title': '유럽 입국자 잇단 확진…특별입국절차 전세계 확대 준비'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '276,622',
#  'like': '2,508',
#  'link': 'https://tv.naver.com/v/10886485/list/67096',
#  'program': '전국TOP10 가요쇼',
#  'title': '낭만에 대하여 - 영텐(임영웅, 영탁), 전국TOP10가요쇼'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '4,744',
#  'like': '46',
#  'link': 'https://tv.naver.com/v/12879994/list/67096',
#  'program': '복면가왕',
#  'title': "'강변북로' 3라운드 무대 - 바보같은 미소"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '2,366,161',
#  'like': '21,213',
#  'link': 'https://tv.naver.com/v/12584114/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 ‘보라빛 엽서’♩ 심금을 울리는 목소리 ˘-˘乃'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,730,398',
#  'like': '16,414',
#  'link': 'https://tv.naver.com/v/12711904/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 vs 김수찬 ‘울면서 후회하네’♪ ✰환상의 하모니✰'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '121,034',
#  'like': '928',
#  'link': 'https://tv.naver.com/v/12590610/list/67096',
#  'program': '신통방통',
#  'title': "설운도·주현미·남진도 반했다…'미스터트롯' 레전드 무대는?"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '856,470',
#  'like': '8,222',
#  'link': 'https://tv.naver.com/v/12840081/list/67096',
#  'program': '미스터트롯',
#  'title': '최저점이 94점 ㅎㄷㄷ; 점수판 실화..? 점수의 배신자'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '8,187',
#  'like': '1',
#  'link': 'https://tv.naver.com/v/12879831/list/67096',
#  'program': 'JTBC뉴스',
#  'title': '텅 빈 명동·홍대…자영업, 매출 급감·줄줄이 임시휴업'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '7,265',
#  'like': '11',
#  'link': 'https://tv.naver.com/v/12880660/list/67096',
#  'program': 'MBC뉴스',
#  'title': '개학 최소 1주일 이상 연기…빠르면 내일 결정'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '373,219',
#  'like': '8,382',
#  'link': 'https://tv.naver.com/v/12839194/list/67096',
#  'program': '미스터트롯',
#  'title': '찬또한테 딱!딱! 붙어라♥ 이찬원 ‘딱풀’♫'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '365,322',
#  'like': '5,810',
#  'link': 'https://tv.naver.com/v/12839709/list/67096',
#  'program': '미스터트롯',
#  'title': '할아버지를 향한 그리움..ㅠㅠ 정동원 ‘누가 울어’♩'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '11,747',
#  'like': '43',
#  'link': 'https://tv.naver.com/v/12876549/list/67096',
#  'program': '김광현 (세인트루이스 카디널스)',
#  'title': "'다시보는 김광현' 미네소타전 3이닝 4K 무실점 현지코멘터리"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '114,403',
#  'like': '857',
#  'link': 'https://tv.naver.com/v/12869991/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '[메이킹] 단밤VS장가 웃음 터지는 ★최강포차★ 요리 대회 현장'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '2,926,591',
#  'like': '27,775',
#  'link': 'https://tv.naver.com/v/12463458/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 ‘어느 60대 노부부 이야기’♩ 첫 소절에 찡≋'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '52,848',
#  'like': '88',
#  'link': 'https://tv.naver.com/v/12816258/list/67096',
#  'program': '김형준의 인사이드MLB',
#  'title': '류현진보다 프라이스, 다저스의 선택은? | 김형준'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '36,684',
#  'like': '1,212',
#  'link': 'https://tv.naver.com/v/12871555/list/67096',
#  'program': '전지적 참견시점',
#  'title': '자동으로 지갑이 열리는 태초부터 시작하는 옹성우의 대출 토크!'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '3,694',
#  'like': '18',
#  'link': 'https://tv.naver.com/v/12880005/list/67096',
#  'program': '복면가왕',
#  'title': "부드러운 목소리 '강변북로'의 정체는! 홍서범!"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '5,819',
#  'like': '36',
#  'link': 'https://tv.naver.com/v/12879577/list/67096',
#  'program': '복면가왕',
#  'title': "매혹적인 음색 '컵라면'의 정체는! 리틀 혜은이 요요미!"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '11,449',
#  'like': '104',
#  'link': 'https://tv.naver.com/v/12878321/list/67096',
#  'program': '런닝맨',
#  'title': '‘시청률 요정’ 임수향, 복학생 언니로 컴백! (ft. 프로게이머 소민)'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '164,281',
#  'like': '1,668',
#  'link': 'https://tv.naver.com/v/12869504/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '스윗♡하게 협박하는 박서준 ＂지금 움직이면, 너 해고야♨＂'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '148,061',
#  'like': '491',
#  'link': 'https://tv.naver.com/v/12869660/list/67096',
#  'program': '하이바이마마',
#  'title': '[8화 예고]′유리야..′ 김태희를 찾아온 의문의 남자?'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '5,226',
#  'like': '3',
#  'link': 'https://tv.naver.com/v/12880329/list/67096',
#  'program': 'TV조선 뉴스',
#  'title': "'코로나19' 걱정에도 수만 인파 꽃구경…방역 '골머리'"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '7,740',
#  'like': '50',
#  'link': 'https://tv.naver.com/v/12881022/list/67096',
#  'program': '사랑은 뷰티풀 인생은 원더풀',
#  'title': '함께 떠나자는 김재영 제안에 설인아의 반응 ＂이거 지금 프러포즈 아니에요?＂'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '108,318',
#  'like': '387',
#  'link': 'https://tv.naver.com/v/12867654/list/67096',
#  'program': '미운 우리 새끼',
#  'title': '[선공개] 홍진영, ‘트롯퀸’ 김연자 드레스 보고 반짝이 의상 홀릭!'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '96,976',
#  'like': '376',
#  'link': 'https://tv.naver.com/v/12869700/list/67096',
#  'program': '하이에나',
#  'title': '황보라, 뻔뻔한 김혜수에 당황! (ft. 비서와 한판 대결)'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '126,874',
#  'like': '1,387',
#  'link': 'https://tv.naver.com/v/12869334/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '이제서야 내가 조금은 여자로 느껴지나 보다…'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '144,117',
#  'like': '982',
#  'link': 'https://tv.naver.com/v/12873342/list/67096',
#  'program': '집사부일체',
#  'title': '[선공개] 이상윤·육성재, 눈물과 함께한 집사부일체와의 마지막'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '55,507',
#  'like': '270',
#  'link': 'https://tv.naver.com/v/12870200/list/67096',
#  'program': '하이에나',
#  'title': '김혜수, 대부업체 이규섭에 카리스마 협박! (ft. 쭈글미 황보라)'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '88,664',
#  'like': '1,928',
#  'link': 'https://tv.naver.com/v/12501788/list/67096',
#  'program': '복면가왕',
#  'title': "'주전자' vs  '주윤발' 1라운드 무대 - 단발머리"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '4,075',
#  'like': '17',
#  'link': 'https://tv.naver.com/v/12879626/list/67096',
#  'program': '복면가왕',
#  'title': "'강변북로' 2라운드 무대 - 열애"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '159,219',
#  'like': '1,355',
#  'link': 'https://tv.naver.com/v/12868653/list/67096',
#  'program': '아는 형님',
#  'title': "김무열의 뜻밖의 실수로 벌어진 윤승아와 '공개 연애' (^//^)"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '298,895',
#  'like': '614',
#  'link': 'https://tv.naver.com/v/12853907/list/67096',
#  'program': 'WKBL(한국여자농구연맹)',
#  'title': '[궁금한이야기W] 여농선수들은 한 손으로 공을 잡을 수 있을까?'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '9,100',
#  'like': '76',
#  'link': 'https://tv.naver.com/v/12878771/list/67096',
#  'program': '런닝맨',
#  'title': '힘없는 유재석, 힘 있는 김종국 한마디에 깨갱!'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '8,390',
#  'like': '187',
#  'link': 'https://tv.naver.com/v/12878533/list/67096',
#  'program': '런닝맨',
#  'title': '‘가위눌리는 거 보여주마!’ 송지효, 나름 설득력 있는 MT 계획'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '14,250',
#  'like': '13',
#  'link': 'https://tv.naver.com/v/12876904/list/67096',
#  'program': 'MLB 핫클립',
#  'title': "'2020시즌 메이저리그 홈런왕 후보들'"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '9,753',
#  'like': '426',
#  'link': 'https://tv.naver.com/v/12876108/list/67096',
#  'program': '슬기로운 의사생활',
#  'title': '[메이킹] 99즈 5인방과 특급 카메오까지! 시작부터 개꿀잼 촬영 현장♥'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '9,544',
#  'like': '50',
#  'link': 'https://tv.naver.com/v/12878378/list/67096',
#  'program': '런닝맨',
#  'title': '[폭소] 김종국, PPT 모르는 지석진에 뼈 때리는 극딜!'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,771,003',
#  'like': '16,824',
#  'link': 'https://tv.naver.com/v/11725060/list/67096',
#  'program': '미스터트롯',
#  'title': '♨참가자 견제 1순위♨ 노사연 기립박수↗ 임영웅 ‘바램’ ♫'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '6,934',
#  'like': '8',
#  'link': 'https://tv.naver.com/v/12880796/list/67096',
#  'program': 'MBC뉴스',
#  'title': "목사 부부도 '확진'…일부 교회 예배 강행"}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '269,938',
#  'like': '2,068',
#  'link': 'https://tv.naver.com/v/12838823/list/67096',
#  'program': '미스터트롯',
#  'title': '장민호 ☆EDM★전사로 돌아오다!! ‘역쩐인생’♪'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '401,250',
#  'like': '1,336',
#  'link': 'https://tv.naver.com/v/12858695/list/67096',
#  'program': '미스터트롯',
#  'title': '대한민국 15%!! 773만 국민이 선택한 미스터트롯 진은?_미스터트롯 12회 예고'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '139,531',
#  'like': '1,572',
#  'link': 'https://tv.naver.com/v/12869625/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '[합리화] 좋아한다고 말할 수 있는 자격이 필요해…'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,374,151',
#  'like': '16,059',
#  'link': 'https://tv.naver.com/v/12036004/list/67096',
#  'program': '미스터트롯',
#  'title': '영탁 ‘막걸리 한잔’♭ 모두 막걸리 열풍! 일.동.원.샷'}
# 2020-03-15 22:08:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '67,408',
#  'like': '1,046',
#  'link': 'https://tv.naver.com/v/12870384/list/67096',
#  'program': '미스터트롯',
#  'title': "♚4위·5위♚ '천상의 목소리' 김호중과 '열네 살의 소년' 정동원"}
# 2020-03-15 22:08:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '4,246',
#  'like': '100',
#  'link': 'https://tv.naver.com/v/12880603/list/67096',
#  'program': '복면가왕',
#  'title': '＜주윤발! 3연승을 향해 돌진?!＞ 복면가왕 247회 예고'}
# 2020-03-15 22:08:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '159,340',
#  'like': '2,030',
#  'link': 'https://tv.naver.com/v/12834618/list/67096',
#  'program': '슈퍼맨이 돌아왔다',
#  'title': '슈퍼맨이 돌아왔다 321회 티저 - 윌벤져스네'}
# 2020-03-15 22:08:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '3,182',
#  'like': '10',
#  'link': 'https://tv.naver.com/v/12880193/list/67096',
#  'program': 'TV조선 뉴스',
#  'title': '"아버지가 주신 선물"…\'미스터트롯\' 진 임영웅'}
# 2020-03-15 22:08:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '66,915',
#  'like': '1,770',
#  'link': 'https://tv.naver.com/v/12868562/list/67096',
#  'program': '놀면 뭐하니?',
#  'title': '※집중※ 본격 감상 시간~ 간질간질한 목소리와 흥겨운 멜로디~♬'}
# 2020-03-15 22:08:14 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '7,609',
#  'like': '44',
#  'link': 'https://tv.naver.com/v/12881320/list/67096',
#  'program': '사랑은 뷰티풀 인생은 원더풀',
#  'title': '사무치는 그리움에 마늘 까는 오민석, 박해미의 분노의 소금 뿌리기!'}
# 2020-03-15 22:08:14 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-03-15 22:08:14 [scrapy.extensions.feedexport] INFO: Stored csv feed (100 items) in: items.csv
# 2020-03-15 22:08:14 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 213,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 31751,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.895099,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 3, 15, 13, 8, 14, 22187),
#  'item_scraped_count': 100,
#  'log_count/DEBUG': 101,
#  'log_count/INFO': 11,
#  'memusage/max': 60940288,
#  'memusage/startup': 60940288,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 3, 15, 13, 8, 13, 127088)}
# 2020-03-15 22:08:14 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ### 4. settings.py 수정

# %%
! head -n 22 navertv/navertv/settings.py | tail -n 2
# Out:
# # Obey robots.txt rules
# ROBOTSTXT_OBEY = True

# %%
! sed -i 's/ROBOTSTXT_OBEY = True/ROBOTSTXT_OBEY = False/' navertv/navertv/settings.py

# %%
! head -n 22 navertv/navertv/settings.py | tail -n 2
# Out:
# # Obey robots.txt rules
# ROBOTSTXT_OBEY = False

# %%
! ./run.sh
# Out:
# 2020-03-15 16:18:10 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: navertv)
# 2020-03-15 16:18:10 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.6.9 (default, Jan 17 2020, 08:43:56) - [GCC 7.4.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-1060-aws-x86_64-with-debian-buster-sid
# 2020-03-15 16:18:10 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'navertv', 'FEED_FORMAT': 'csv', 'FEED_URI': 'items.csv', 'NEWSPIDER_MODULE': 'navertv.spiders', 'SPIDER_MODULES': ['navertv.spiders']}
# 2020-03-15 16:18:10 [scrapy.extensions.telnet] INFO: Telnet Password: 098c4b898d67281a
# 2020-03-15 16:18:10 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-03-15 16:18:10 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-03-15 16:18:10 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-03-15 16:18:10 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-03-15 16:18:10 [scrapy.core.engine] INFO: Spider opened
# 2020-03-15 16:18:10 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-03-15 16:18:10 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-03-15 16:18:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://tv.naver.com/r/> (referer: None)
# 2020-03-15 16:18:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '709,810',
#  'like': '6,180',
#  'link': 'https://tv.naver.com/v/12870385/list/67096',
#  'program': '하이에나',
#  'title': '[찐한 엔딩] 김혜수♡주지훈, 격정적인 KISS♥'}
# 2020-03-15 16:18:10 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '109,465',
#  'like': '719',
#  'link': 'https://tv.naver.com/v/12873342/list/67096',
#  'program': '집사부일체',
#  'title': '[선공개] 이상윤·육성재, 눈물과 함께한 집사부일체와의 마지막'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '79,934',
#  'like': '276',
#  'link': 'https://tv.naver.com/v/12867654/list/67096',
#  'program': '미운 우리 새끼',
#  'title': '[선공개] 홍진영, ‘트롯퀸’ 김연자 드레스 보고 반짝이 의상 홀릭!'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,659,992',
#  'like': '19,828',
#  'link': 'https://tv.naver.com/v/12840075/list/67096',
#  'program': '미스터트롯',
#  'title': '☞눈물주의☜ 임영웅 ‘배신자’♭ 얄밉게 떠난 님아☹'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '456,428',
#  'like': '3,807',
#  'link': 'https://tv.naver.com/v/12869932/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '[충격 엔딩] 나는… 네가 지금 미치도록 보고 싶다'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '413,612',
#  'like': '5,681',
#  'link': 'https://tv.naver.com/v/12870388/list/67096',
#  'program': '미스터트롯',
#  'title': '♛진(眞)·선(善)♛ ‘영웅이냐 영탁이냐’ 진은 임.영.웅'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '950,205',
#  'like': '16,766',
#  'link': 'https://tv.naver.com/v/12839921/list/67096',
#  'program': '미스터트롯',
#  'title': '순이밖에 모르는 찬또..♡ 이찬원 ‘18세 순이’♪'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '354,806',
#  'like': '3,804',
#  'link': 'https://tv.naver.com/v/12869650/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '김다미를 향한 마음을 깨달은 박서준 「온통 너다…」'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '58,336',
#  'like': '2,709',
#  'link': 'https://tv.naver.com/v/12866190/list/67096',
#  'program': '쇼! 음악중심',
#  'title': 'NCT 127 -영웅(英雄), (NCT 127 -Kick It)'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '480,402',
#  'like': '7,835',
#  'link': 'https://tv.naver.com/v/12839270/list/67096',
#  'program': '미스터트롯',
#  'title': '✪주먹 장인✪ 임히어로 출격↗ 임영웅 ‘두 주먹’♩'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '20,863',
#  'like': '2,442',
#  'link': 'https://tv.naver.com/v/12865955/list/67096',
#  'program': '쇼! 음악중심',
#  'title': '빅톤 -Howling (VICTON  -Howling)'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '551,977',
#  'like': '11,974',
#  'link': 'https://tv.naver.com/v/12839035/list/67096',
#  'program': '미스터트롯',
#  'title': '✦탁마에의 탄생✧ 엄지 척乃 영탁 ‘찐이야’♬'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '422,514',
#  'like': '7,054',
#  'link': 'https://tv.naver.com/v/12838898/list/67096',
#  'program': '미스터트롯',
#  'title': '14살에 깨우친 인생..✰ 정동원 ‘여백’♪'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '152,857',
#  'like': '1,402',
#  'link': 'https://tv.naver.com/v/12869416/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '김동희와 함께 있는 김다미에 혼란스러운 박서준'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '102,911',
#  'like': '3,103',
#  'link': 'https://tv.naver.com/v/12870387/list/67096',
#  'program': '미스터트롯',
#  'title': "✿미(美)✿ '찬또배기' 이찬원의 진심 어린 수상 소감☺"}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '11,631',
#  'like': '9',
#  'link': 'https://tv.naver.com/v/12852489/list/67096',
#  'program': '한국경제TV - 신속한 경제/증권 채널',
#  'title': "초콜릿 폭포로 만드는 국민 간식 '초코파이' 제조공정 [제조의 비밀]"}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '148,352',
#  'like': '1,258',
#  'link': 'https://tv.naver.com/v/12868653/list/67096',
#  'program': '아는 형님',
#  'title': "김무열의 뜻밖의 실수로 벌어진 윤승아와 '공개 연애' (^//^)"}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '394,630',
#  'like': '10,639',
#  'link': 'https://tv.naver.com/v/12839699/list/67096',
#  'program': '미스터트롯',
#  'title': '트바로티 인생곡! 은사님께 드리는 노래... ‘고맙소’♩'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '50,971',
#  'like': '1,574',
#  'link': 'https://tv.naver.com/v/12868562/list/67096',
#  'program': '놀면 뭐하니?',
#  'title': '※집중※ 본격 감상 시간~ 간질간질한 목소리와 흥겨운 멜로디~♬'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '438,000',
#  'like': '7,155',
#  'link': 'https://tv.naver.com/v/12839883/list/67096',
#  'program': '미스터트롯',
#  'title': '음악에 대한 갈망.. 영탁 ‘내 삶의 이유있음은’♫'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '41,687',
#  'like': '305',
#  'link': 'https://tv.naver.com/v/12868982/list/67096',
#  'program': '아는 형님',
#  'title': '송지효의 술 버릇 ☞ 조명감독님 패딩 속에 양말 ☆투척☆'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '176,763',
#  'like': '621',
#  'link': 'https://tv.naver.com/v/12861163/list/67096',
#  'program': 'Talk about K LEAGUE',
#  'title': '[13년전, 오늘] 뭉쳐야 찬다 감독님 어마어마했던 현역시절 (2007.03.14)'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '204,744',
#  'like': '2,302',
#  'link': 'https://tv.naver.com/v/12869765/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '박서준, 연적 김동희를 향한 선포 ＂내가 다미 좋아한다-＂'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '252,565',
#  'like': '1,098',
#  'link': 'https://tv.naver.com/v/12870438/list/67096',
#  'program': '하이에나',
#  'title': '[3월 20일 예고] 주지훈, 연락 안 되는 김혜수에 질투!'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '2,356,721',
#  'like': '21,171',
#  'link': 'https://tv.naver.com/v/12584114/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 ‘보라빛 엽서’♩ 심금을 울리는 목소리 ˘-˘乃'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '152,987',
#  'like': '2,292',
#  'link': 'https://tv.naver.com/v/12870179/list/67096',
#  'program': '하이에나',
#  'title': '“보고 싶어 왔다… 배알도 없이” 주지훈, 김혜수에 취중 고백♥'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '101,452',
#  'like': '798',
#  'link': 'https://tv.naver.com/v/12869991/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '[메이킹] 단밤VS장가 웃음 터지는 ★최강포차★ 요리 대회 현장'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '363,572',
#  'like': '8,307',
#  'link': 'https://tv.naver.com/v/12839194/list/67096',
#  'program': '미스터트롯',
#  'title': '찬또한테 딱!딱! 붙어라♥ 이찬원 ‘딱풀’♫'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '176,744',
#  'like': '5,985',
#  'link': 'https://tv.naver.com/v/12866192/list/67096',
#  'program': '쇼! 음악중심',
#  'title': '양준일 + 리아 킴 -Dance With Me 아가씨 (Yang Joon Il + Lia Kim -Dance with '
#           'me Lady)'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '21,841',
#  'like': '973',
#  'link': 'https://tv.naver.com/v/12871555/list/67096',
#  'program': '전지적 참견시점',
#  'title': '자동으로 지갑이 열리는 태초부터 시작하는 옹성우의 대출 토크!'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '354,728',
#  'like': '5,724',
#  'link': 'https://tv.naver.com/v/12839709/list/67096',
#  'program': '미스터트롯',
#  'title': '할아버지를 향한 그리움..ㅠㅠ 정동원 ‘누가 울어’♩'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '841,560',
#  'like': '8,168',
#  'link': 'https://tv.naver.com/v/12840081/list/67096',
#  'program': '미스터트롯',
#  'title': '최저점이 94점 ㅎㄷㄷ; 점수판 실화..? 점수의 배신자'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '150,206',
#  'like': '1,561',
#  'link': 'https://tv.naver.com/v/12869504/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '스윗♡하게 협박하는 박서준 ＂지금 움직이면, 너 해고야♨＂'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '114,879',
#  'like': '1,296',
#  'link': 'https://tv.naver.com/v/12869334/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '이제서야 내가 조금은 여자로 느껴지나 보다…'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '290,836',
#  'like': '598',
#  'link': 'https://tv.naver.com/v/12853907/list/67096',
#  'program': 'WKBL(한국여자농구연맹)',
#  'title': '[궁금한이야기W] 여농선수들은 한 손으로 공을 잡을 수 있을까?'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '83,771',
#  'like': '346',
#  'link': 'https://tv.naver.com/v/12869700/list/67096',
#  'program': '하이에나',
#  'title': '황보라, 뻔뻔한 김혜수에 당황! (ft. 비서와 한판 대결)'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '57,683',
#  'like': '882',
#  'link': 'https://tv.naver.com/v/12870384/list/67096',
#  'program': '미스터트롯',
#  'title': "♚4위·5위♚ '천상의 목소리' 김호중과 '열네 살의 소년' 정동원"}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,723,365',
#  'like': '16,385',
#  'link': 'https://tv.naver.com/v/12711904/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 vs 김수찬 ‘울면서 후회하네’♪ ✰환상의 하모니✰'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '4,437',
#  'like': '7',
#  'link': 'https://tv.naver.com/v/12876152/list/67096',
#  'program': 'KBS뉴스',
#  'title': '[속고살지마] 개목줄 하랬더니 ‘칼침 맞고 싶냐’는 견주…적반하장에 불면증까지'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '54,939',
#  'like': '365',
#  'link': 'https://tv.naver.com/v/12870320/list/67096',
#  'program': '하이에나',
#  'title': '“내 눈 앞에서 사라져!” 김혜수, 출소한 父에 분노 가득찬 외침!'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '2,920,102',
#  'like': '27,739',
#  'link': 'https://tv.naver.com/v/12463458/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 ‘어느 60대 노부부 이야기’♩ 첫 소절에 찡≋'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '127,950',
#  'like': '1,460',
#  'link': 'https://tv.naver.com/v/12869625/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '[합리화] 좋아한다고 말할 수 있는 자격이 필요해…'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '43,516',
#  'like': '73',
#  'link': 'https://tv.naver.com/v/12816258/list/67096',
#  'program': '김형준의 인사이드MLB',
#  'title': '류현진보다 프라이스, 다저스의 선택은? | 김형준'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '17,435',
#  'like': '69',
#  'link': 'https://tv.naver.com/v/12872242/list/67096',
#  'program': 'SPORTSTIME (스포츠타임)',
#  'title': '[UCL] ‘떠오르는 스타’ 엘링 홀란드, 그가 갖춘 3가지 완벽한 요소'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '473,623',
#  'like': '1,048',
#  'link': 'https://tv.naver.com/v/12820595/list/67096',
#  'program': 'SPOTV_UCL',
#  'title': '리버풀 vs 아틀레티코 마드리드 경기 하이라이트'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '3,892',
#  'like': '2',
#  'link': 'https://tv.naver.com/v/12876192/list/67096',
#  'program': '연합뉴스TV',
#  'title': '사재기 마스크 15만장 자진신고…"시중에 푼다"'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '10,307',
#  'like': '212',
#  'link': 'https://tv.naver.com/v/12873556/list/67096',
#  'program': '1박 2일 시즌4',
#  'title': '[선공개] 복불복 없이 식사 제공하는 제작진...? 느낌이 쎄한 오늘의 목적지는?! [1박 2일 시즌4]'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '383,288',
#  'like': '1,300',
#  'link': 'https://tv.naver.com/v/12858695/list/67096',
#  'program': '미스터트롯',
#  'title': '대한민국 15%!! 773만 국민이 선택한 미스터트롯 진은?_미스터트롯 12회 예고'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '47,531',
#  'like': '243',
#  'link': 'https://tv.naver.com/v/12870200/list/67096',
#  'program': '하이에나',
#  'title': '김혜수, 대부업체 이규섭에 카리스마 협박! (ft. 쭈글미 황보라)'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '37,251',
#  'like': '425',
#  'link': 'https://tv.naver.com/v/12868561/list/67096',
#  'program': '아는 형님',
#  'title': '의도치 않은(?) 김희철의 원 샷 투 킬♨ 맞은 송지효-강호동'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '3,534',
#  'like': '249',
#  'link': 'https://tv.naver.com/v/12876108/list/67096',
#  'program': '슬기로운 의사생활',
#  'title': '[메이킹] 99즈 5인방과 특급 카메오까지! 시작부터 개꿀잼 촬영 현장♥'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '61,883',
#  'like': '141',
#  'link': 'https://tv.naver.com/v/12851575/list/67096',
#  'program': '터치플레이TOUCHPLAY',
#  'title': '대한민국 최고의 슈터를 가린다.'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '33,608',
#  'like': '200',
#  'link': 'https://tv.naver.com/v/12868720/list/67096',
#  'program': '놀면 뭐하니?',
#  'title': '☆장범준 신곡☆ 판테온으로 플레를 간다고?? 로우 레벨 유저의 염원이 담긴 미공개 곡'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '51,018',
#  'like': '552',
#  'link': 'https://tv.naver.com/v/12869933/list/67096',
#  'program': '하이에나',
#  'title': '“그딴 거?” 주지훈, 회식자리에서 김혜수와 신경전!'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '121,855',
#  'like': '437',
#  'link': 'https://tv.naver.com/v/12869660/list/67096',
#  'program': '하이바이마마',
#  'title': '[8화 예고]′유리야..′ 김태희를 찾아온 의문의 남자?'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '115,878',
#  'like': '1,247',
#  'link': 'https://tv.naver.com/v/12869332/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '자상하게 챙겨주는 박서준에 행복한 김다미 ＂완전 감동♡＂'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '264,610',
#  'like': '2,398',
#  'link': 'https://tv.naver.com/v/10886485/list/67096',
#  'program': '전국TOP10 가요쇼',
#  'title': '낭만에 대하여 - 영텐(임영웅, 영탁), 전국TOP10가요쇼'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '263,261',
#  'like': '2,037',
#  'link': 'https://tv.naver.com/v/12838823/list/67096',
#  'program': '미스터트롯',
#  'title': '장민호 ☆EDM★전사로 돌아오다!! ‘역쩐인생’♪'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '48,920',
#  'like': '314',
#  'link': 'https://tv.naver.com/v/12870383/list/67096',
#  'program': '미스터트롯',
#  'title': "♜6위·7위♜ '맏형' 장민호와 '해군병장' 김희재 ^‿^乃"}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '133,906',
#  'like': '1,242',
#  'link': 'https://tv.naver.com/v/12869418/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '주주총회를 앞두고 쓰러진 김다미… 당황한 박서준..!'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '63,974',
#  'like': '290',
#  'link': 'https://tv.naver.com/v/12870322/list/67096',
#  'program': '미스터트롯',
#  'title': '장만호는 무효⚠ 유효 투표수는 ❛5,428,900표❜'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '201,395',
#  'like': '3,223',
#  'link': 'https://tv.naver.com/v/12838896/list/67096',
#  'program': '미스터트롯',
#  'title': '촤-아★ 밀려드는 묵직한 고음 김호중 ‘바람남’♬'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '84,799',
#  'like': '651',
#  'link': 'https://tv.naver.com/v/12869764/list/67096',
#  'program': '하이에나',
#  'title': '“난 좋았어 당신과 일해서♥” 주지훈, 김혜수 말에 ‘복잡한 시선’'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '109,207',
#  'like': '862',
#  'link': 'https://tv.naver.com/v/12590610/list/67096',
#  'program': '신통방통',
#  'title': "설운도·주현미·남진도 반했다…'미스터트롯' 레전드 무대는?"}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '60,405',
#  'like': '629',
#  'link': 'https://tv.naver.com/v/12869992/list/67096',
#  'program': '이태원 클라쓰',
#  'title': '[단독공개] 승권이가 직접 촬영한 새로이&토니 인터뷰!!'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '11,427',
#  'like': '13',
#  'link': 'https://tv.naver.com/v/12875728/list/67096',
#  'program': 'DKTV',
#  'title': '“류현진은 피칭 천재!” MLB 취재 경력 40년차 베테랑 기자의 고백! | DKTV'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '417,375',
#  'like': '941',
#  'link': 'https://tv.naver.com/v/12769455/list/67096',
#  'program': '킼TV',
#  'title': '난 한 순간도 널 안 좋아한 적 없어 [리얼:타임:러브2] EP8'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,765,419',
#  'like': '16,790',
#  'link': 'https://tv.naver.com/v/11725060/list/67096',
#  'program': '미스터트롯',
#  'title': '♨참가자 견제 1순위♨ 노사연 기립박수↗ 임영웅 ‘바램’ ♫'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '51,383',
#  'like': '288',
#  'link': 'https://tv.naver.com/v/12869935/list/67096',
#  'program': '하이에나',
#  'title': '김혜수, 아버지와의 과거를 떠올리며 분노!'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,368,112',
#  'like': '16,011',
#  'link': 'https://tv.naver.com/v/12036004/list/67096',
#  'program': '미스터트롯',
#  'title': '영탁 ‘막걸리 한잔’♭ 모두 막걸리 열풍! 일.동.원.샷'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '205,821',
#  'like': '346',
#  'link': 'https://tv.naver.com/v/12841251/list/67096',
#  'program': 'SPOTV_UEL',
#  'title': 'LASK 린츠 vs 맨체스터 유나이티드 경기 하이라이트'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '10,924',
#  'like': '4',
#  'link': 'https://tv.naver.com/v/12875854/list/67096',
#  'program': '뉴스는 YTN',
#  'title': "스페인 확진자 6천 명 넘어서...'제2의 이탈리아' 되나"}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '5,987',
#  'like': '5',
#  'link': 'https://tv.naver.com/v/12875250/list/67096',
#  'program': '뉴스는 YTN',
#  'title': "'76명 추가 확진' 뚜렷한 감소세...개학 연기 적극 검토"}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '30,351',
#  'like': '355',
#  'link': 'https://tv.naver.com/v/12869020/list/67096',
#  'program': '아는 형님',
#  'title': "뼛속까지 '런닝맨' 송지효의 새벽에 깨어난 질주본능♨"}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '62,939',
#  'like': '1,682',
#  'link': 'https://tv.naver.com/v/12865898/list/67096',
#  'program': '쇼! 음악중심',
#  'title': '있지 -WANNABE (ITZY -WANNABE)'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '42,772',
#  'like': '273',
#  'link': 'https://tv.naver.com/v/12870319/list/67096',
#  'program': '하이에나',
#  'title': '황보라♡전석호, 추억의 장소에서 심쿵 키스♥ (ft. 기억나는 주지훈)'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '306,446',
#  'like': '4,155',
#  'link': 'https://tv.naver.com/v/12840047/list/67096',
#  'program': '미스터트롯',
#  'title': '아버지의 애창곡 ❛눈물 날 것 같아서..❜ ㅠㅠ'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '27,283',
#  'like': '2,353',
#  'link': 'https://tv.naver.com/v/12867719/list/67096',
#  'program': '불후의 명곡2 전설을 노래하다',
#  'title': '빅톤 - 로미오&줄리엣'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '907,662',
#  'like': '16,915',
#  'link': 'https://tv.naver.com/v/12816963/list/67096',
#  'program': '유 퀴즈 온 더 블럭',
#  'title': '유재석을 눈물 쏟게 만든 의료진의 한 마디 ′저는 괜찮습니다′'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '3,447',
#  'like': '1',
#  'link': 'https://tv.naver.com/v/12876029/list/67096',
#  'program': '연합뉴스TV',
#  'title': '경계·지휘 총체적 실패…구멍 뚫린 제주 해군기지'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '40,758',
#  'like': '193',
#  'link': 'https://tv.naver.com/v/12869820/list/67096',
#  'program': '하이에나',
#  'title': '“정금자, 내가 써도 되죠?” 김호정, 이경영에게 내뱉은 야심찬 한 마디!'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '47,585',
#  'like': '259',
#  'link': 'https://tv.naver.com/v/12757550/list/67096',
#  'program': '미운 우리 새끼',
#  'title': '[3월 15일 예고] 옷 값만 큰 거 한 장? 트롯퀸이 떴다!'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '14,178',
#  'like': '68',
#  'link': 'https://tv.naver.com/v/12871385/list/67096',
#  'program': '전지적 참견시점',
#  'title': '아니.. 이것은.. 미미?! 모닝 비빔면 흡입하는 배운 먹방러 김신영...☆'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '79,923',
#  'like': '680',
#  'link': 'https://tv.naver.com/v/12869631/list/67096',
#  'program': '하이바이마마',
#  'title': '[에필로그]또 다른 나의 꽃, 김태희의 빈자리에 남겨진 것들'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '235,960',
#  'like': '2,003',
#  'link': 'https://tv.naver.com/v/12849864/list/67096',
#  'program': '미스터트롯',
#  'title': '“오늘은 아이돌 느낌으로”ㅎㅎ ✿뽕미남✿ 꽃단장 中 '}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '2,770',
#  'like': '0',
#  'link': 'https://tv.naver.com/v/12876307/list/67096',
#  'program': '채널A뉴스',
#  'title': '“한국 검사 방식 최고”…해외서 호평 받은 ‘드라이브 스루’'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '46,189',
#  'like': '44',
#  'link': 'https://tv.naver.com/v/12872960/list/67096',
#  'program': 'MBC뉴스',
#  'title': '수백 명 모아놓고 강연이라니…중단 권고도 무시'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '172,156',
#  'like': '1,221',
#  'link': 'https://tv.naver.com/v/12869479/list/67096',
#  'program': '하이바이마마',
#  'title': '＂나 언제까지 아무것도 하지 마?＂ 김태희와 어떻게든 함께하고 싶은 이규형ㅠㅠ'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '33,989',
#  'like': '345',
#  'link': 'https://tv.naver.com/v/12868915/list/67096',
#  'program': '아는 형님',
#  'title': '강호동의 속사포 멘탈 공격에♨ 유재석 보고 싶은 송지효 T^T'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,336',
#  'like': '1',
#  'link': 'https://tv.naver.com/v/12876043/list/67096',
#  'program': '연합뉴스TV',
#  'title': "[뉴스특보] 코로나19 증가세 '주춤'…집단감염 지속 '긴장'"}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '29,814',
#  'like': '24',
#  'link': 'https://tv.naver.com/v/12808460/list/67096',
#  'program': '모터리언 Motorian',
#  'title': '신형 아반떼에서 페라리와 람보르기니 냄새가! Hyundai New Avante'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '56,892',
#  'like': '385',
#  'link': 'https://tv.naver.com/v/12869124/list/67096',
#  'program': '하이바이마마',
#  'title': '뜻밖의 동병상련(?) 묘하게 통하는 김태희&고보결'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '107,130',
#  'like': '588',
#  'link': 'https://tv.naver.com/v/12869562/list/67096',
#  'program': '하이바이마마',
#  'title': '김태희X고보결과 마주친 이규형X이시우! 무슨 상황?! ㄴㅇ0ㅇㄱ'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,854,772',
#  'like': '19,196',
#  'link': 'https://tv.naver.com/v/12116952/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 ‘일편단심 민들레야’♪ #안정 #섬세 #완벽 #✌'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '15,324',
#  'like': '20',
#  'link': 'https://tv.naver.com/v/12872977/list/67096',
#  'program': 'OSEN',
#  'title': '[O!SPORTS] “이게 뭐라고 긴장이 되나” KIA 양현종 ‘신무기 연마’ 밀착캠'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '2,149',
#  'like': '2',
#  'link': 'https://tv.naver.com/v/12876408/list/67096',
#  'program': '채널A뉴스',
#  'title': '강남 아파트 흔드는 코로나…석 달 만에 5억 ‘뚝’'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '47,753',
#  'like': '506',
#  'link': 'https://tv.naver.com/v/12869936/list/67096',
#  'program': '하이에나',
#  'title': '“너 아직도 김혜수 좋아하냐?” 주지훈, 취해 묻는 전석호 ‘귀뺨 스매싱’'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,073,739',
#  'like': '12,781',
#  'link': 'https://tv.naver.com/v/12711899/list/67096',
#  'program': '미스터트롯',
#  'title': '✲깜찍·귀염·잘생김✲ 정동원 vs 장민호 ‘파트너’♫ '}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '29,312',
#  'like': '72',
#  'link': 'https://tv.naver.com/v/12867206/list/67096',
#  'program': '김광현 (세인트루이스 카디널스)',
#  'title': '[시범경기 몰아보기] 김광현, KK의 위엄을 미국땅에 알리다 (8이닝 11K 무실점)'}
# 2020-03-15 16:18:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '33,297',
#  'like': '1,582',
#  'link': 'https://tv.naver.com/v/12870488/list/67096',
#  'program': '전지적 참견시점',
#  'title': '움직이는 조각상 옹비드♡ 예능 적응 100% 옹성우의 명품 댄스'}
# 2020-03-15 16:18:11 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-03-15 16:18:11 [scrapy.extensions.feedexport] INFO: Stored csv feed (100 items) in: items.csv
# 2020-03-15 16:18:11 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 213,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 32012,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.73505,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 3, 15, 7, 18, 11, 312306),
#  'item_scraped_count': 100,
#  'log_count/DEBUG': 101,
#  'log_count/INFO': 11,
#  'memusage/max': 56020992,
#  'memusage/startup': 56020992,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 3, 15, 7, 18, 10, 577256)}
# 2020-03-15 16:18:11 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ### 5. pipeline.py 설정

# %%
# %%writefile navertv/navertv/mongodb.py
import pymongo

client = pymongo.MongoClient('mongodb://minhye:dss@15.164.13.131:27017')
db = client.navertv
collection = db.data
# Out:
# Writing navertv/navertv/mongodb.py

# %%
# !cat navertv/navertv/pipelines.py
# Out:
# # -*- coding: utf-8 -*-
#
# # Define your item pipelines here
# #
# # Don't forget to add your pipeline to the ITEM_PIPELINES setting
# # See: https://docs.scrapy.org/en/latest/topics/item-pipeline.html
#
#
# class NavertvPipeline(object):
#     def process_item(self, item, spider):
#         return item

# %%
# %%writefile navertv/navertv/pipelines.py
import requests
from bs4 import BeautifulSoup
from .mongodb import collection

class NavertvPipeline(object):
    
    def process_item(self, item, spider):
        data = {
            "title": item["title"],
            "program": item["program"],
            "count": item["count"],
            "like": item["like"],
            "link": item["link"],
        }
        collection.insert(data)
        
        return item
# Out:
# Overwriting navertv/navertv/pipelines.py

# %%
# settings.py에서 파이프라인 연결

# %%
# !echo "ITEM_PIPELINES = {" >> navertv/navertv/settings.py

# %%
# !echo "    'navertv.pipelines.NavertvPipeline': 300," >> navertv/navertv/settings.py

# %%
# !echo "}" >> navertv/navertv/settings.py

# %%
# !tail -n 3 navertv/navertv/settings.py
# Out:
# ITEM_PIPELINES = {
#     'navertv.pipelines.NavertvPipeline': 300,
# }

# %%
! navertv/run.sh
# Out:
# 2020-03-18 13:59:00 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: navertv)
# 2020-03-18 13:59:00 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.6.9 (default, Jan 17 2020, 08:43:56) - [GCC 7.4.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Linux-4.15.0-1060-aws-x86_64-with-debian-buster-sid
# 2020-03-18 13:59:00 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'navertv', 'FEED_FORMAT': 'csv', 'FEED_URI': 'items.csv', 'NEWSPIDER_MODULE': 'navertv.spiders', 'SPIDER_MODULES': ['navertv.spiders']}
# 2020-03-18 13:59:00 [scrapy.extensions.telnet] INFO: Telnet Password: e6941fb5480d7bff
# 2020-03-18 13:59:00 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-03-18 13:59:00 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-03-18 13:59:00 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-03-18 13:59:00 [scrapy.middleware] INFO: Enabled item pipelines:
# ['navertv.pipelines.NavertvPipeline']
# 2020-03-18 13:59:00 [scrapy.core.engine] INFO: Spider opened
# 2020-03-18 13:59:00 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-03-18 13:59:00 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-03-18 13:59:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://tv.naver.com/r/> (referer: None)
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '211,375',
#  'like': '344',
#  'link': 'https://tv.naver.com/v/12921002/list/67096',
#  'program': '아내의 맛',
#  'title': '❴안절부절❵감정싸움.. 마마 비행기 티켓팅 진행 ʘ_ʘ'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '76,252',
#  'like': '271',
#  'link': 'https://tv.naver.com/v/12918462/list/67096',
#  'program': '트롯신이 떴다',
#  'title': '[선공개] 트로트를 세계로 알릴 장윤정의 뭉클한 무대!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '98,541',
#  'like': '205',
#  'link': 'https://tv.naver.com/v/12920957/list/67096',
#  'program': '아내의 맛',
#  'title': '위장 설렘❤ 마마:혜정:시우 딸기 쟁탈전 (츄릅-)'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '125,954',
#  'like': '183',
#  'link': 'https://tv.naver.com/v/12924801/list/67096',
#  'program': 'SBS뉴스',
#  'title': '[영상] 해외서 난리 난 강경화 장관…실제 현지인 생각은?'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '45,713',
#  'like': '91',
#  'link': 'https://tv.naver.com/v/12920466/list/67096',
#  'program': '불타는 청춘',
#  'title': '‘너희 뭐하냐?’ 안혜경♥구본승, 계약커플에서 이젠 실제커플로?'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '178,177',
#  'like': '312',
#  'link': 'https://tv.naver.com/v/12920951/list/67096',
#  'program': '아내의 맛',
#  'title': '✖집안 박살✖ 숨 막히는 물감 총싸움»» 짠소원 등장..'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '126,565',
#  'like': '298',
#  'link': 'https://tv.naver.com/v/12921003/list/67096',
#  'program': '아내의 맛',
#  'title': '눈가 촉촉 ㅜㅜ 꼬여버린 고부지간 ▹이대로 중국 귀환?'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '91,986',
#  'like': '107',
#  'link': 'https://tv.naver.com/v/12920994/list/67096',
#  'program': '아내의 맛',
#  'title': '⚠거품 폭탄⚠ 제조 “신나? 야 나두!” 치약 폭발✌'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,949,667',
#  'like': '20,734',
#  'link': 'https://tv.naver.com/v/12840075/list/67096',
#  'program': '미스터트롯',
#  'title': '☞눈물주의☜ 임영웅 ‘배신자’♭ 얄밉게 떠난 님아☹'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '86,735',
#  'like': '3,968',
#  'link': 'https://tv.naver.com/v/12866190/list/67096',
#  'program': '쇼! 음악중심',
#  'title': 'NCT 127 -영웅(英雄), (NCT 127 -Kick It)'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '92,022',
#  'like': '189',
#  'link': 'https://tv.naver.com/v/12920547/list/67096',
#  'program': '아내의 맛',
#  'title': '짠소원 드.디.어 ✦새 옷✧ 5년 묵은 유물..ㅋㅋ'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '553,831',
#  'like': '8,389',
#  'link': 'https://tv.naver.com/v/12839270/list/67096',
#  'program': '미스터트롯',
#  'title': '✪주먹 장인✪ 임히어로 출격↗ 임영웅 ‘두 주먹’♩'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '54,882',
#  'like': '94',
#  'link': 'https://tv.naver.com/v/12920624/list/67096',
#  'program': '아내의 맛',
#  'title': '❀짠린이집 오픈❀ 마마 ˹인생 연기˼ 구연동화 ♪'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,087,131',
#  'like': '17,435',
#  'link': 'https://tv.naver.com/v/12839921/list/67096',
#  'program': '미스터트롯',
#  'title': '순이밖에 모르는 찬또..♡ 이찬원 ‘18세 순이’♪'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '44,344',
#  'like': '55',
#  'link': 'https://tv.naver.com/v/12722602/list/67096',
#  'program': 'UNICON',
#  'title': '명배우 유해진을 울린 건달 전문 배우'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '67,293',
#  'like': '200',
#  'link': 'https://tv.naver.com/v/12919945/list/67096',
#  'program': '방법',
#  'title': "[희망 엔딩] '혼자 짊어지지 마' 의식불명 정지소, 엄지원은 포기 안 해!"}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '7,697',
#  'like': '48',
#  'link': 'https://tv.naver.com/v/12925324/list/67096',
#  'program': '이영미의 스포츠 in 스토리',
#  'title': '‘애리조나판’ 추 혼자 산다! <1>편(3월 5일 촬영)'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '529,340',
#  'like': '7,664',
#  'link': 'https://tv.naver.com/v/12838898/list/67096',
#  'program': '미스터트롯',
#  'title': '14살에 깨우친 인생..✰ 정동원 ‘여백’♪'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '12,403',
#  'like': '40',
#  'link': 'https://tv.naver.com/v/12922858/list/67096',
#  'program': 'DKTV',
#  'title': '토론토 클럽하우스에는 류현진 라인이 있다? 클럽하우스의 비밀! | DKTV'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '672,934',
#  'like': '12,858',
#  'link': 'https://tv.naver.com/v/12839035/list/67096',
#  'program': '미스터트롯',
#  'title': '✦탁마에의 탄생✧ 엄지 척乃 영탁 ‘찐이야’♬'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '251,727',
#  'like': '4,395',
#  'link': 'https://tv.naver.com/v/12880188/list/67096',
#  'program': '복면가왕',
#  'title': "'주윤발' 의 가왕 방어전 무대 - 멀어지다\r\n"}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '55,984',
#  'like': '95',
#  'link': 'https://tv.naver.com/v/12922817/list/67096',
#  'program': '중앙일보',
#  'title': "[영상]日만 빼고 세계 극찬…韓 '드라이브 스루' 또 진화했다"}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '167,133',
#  'like': '490',
#  'link': 'https://tv.naver.com/v/12902859/list/67096',
#  'program': '동상이몽2_너는 내 운명',
#  'title': '[보안 유지] 박시은, 이제야 밝혀지는 데뷔의 진실!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '10,447',
#  'like': '49',
#  'link': 'https://tv.naver.com/v/12920587/list/67096',
#  'program': '불타는 청춘',
#  'title': '신효범, ‘컬투쇼×불청’ 콜라보 실제 성사에 흥분!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '490,836',
#  'like': '11,475',
#  'link': 'https://tv.naver.com/v/12839699/list/67096',
#  'program': '미스터트롯',
#  'title': '트바로티 인생곡! 은사님께 드리는 노래... ‘고맙소’♩'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '82,072',
#  'like': '1,089',
#  'link': 'https://tv.naver.com/v/12918737/list/67096',
#  'program': '날씨가 좋으면 찾아가겠어요',
#  'title': '[직진 엔딩] ＂네가 좋아＂ 한치의 고민 없는 박민영의 고백♥'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '12,578',
#  'like': '29',
#  'link': 'https://tv.naver.com/v/12924117/list/67096',
#  'program': '맛 좀 보실래요',
#  'title': '[반전] 스윗남 안지훈, 한가림 돈 보고 들이댄 ‘속물!’'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '2,979,925',
#  'like': '28,032',
#  'link': 'https://tv.naver.com/v/12463458/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 ‘어느 60대 노부부 이야기’♩ 첫 소절에 찡≋'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '9,760',
#  'like': '1',
#  'link': 'https://tv.naver.com/v/12925650/list/67096',
#  'program': '뉴스는 YTN',
#  'title': '[현장영상] "117만 가구에 최대 50만 원 지급 예정"'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '41,045',
#  'like': '111',
#  'link': 'https://tv.naver.com/v/12919888/list/67096',
#  'program': '방법',
#  'title': '악귀를 품은 정지소, 활활 타버린 성동일! 그리고 일상으로 돌아간 사람들'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '2,427,565',
#  'like': '21,408',
#  'link': 'https://tv.naver.com/v/12584114/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 ‘보라빛 엽서’♩ 심금을 울리는 목소리 ˘-˘乃'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,779,513',
#  'like': '16,558',
#  'link': 'https://tv.naver.com/v/12711904/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 vs 김수찬 ‘울면서 후회하네’♪ ✰환상의 하모니✰'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '59,835',
#  'like': '156',
#  'link': 'https://tv.naver.com/v/12899521/list/67096',
#  'program': '서형욱의 뽈리TV',
#  'title': '손흥민이 토트넘 에이스인 근거 알려드릴게요'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '22,518',
#  'like': '65',
#  'link': 'https://tv.naver.com/v/12922886/list/67096',
#  'program': 'MBN 뉴스',
#  'title': 'IOC "올림픽 정상 개최" 의지 재확인…유로2020 1년 연기'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '10,448',
#  'like': '76',
#  'link': 'https://tv.naver.com/v/12848770/list/67096',
#  'program': '트롯신이 떴다',
#  'title': '[스페셜] ★꿀잼 보장★ 트롯신의 예능 폭발 장면들 大 공개!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '892,712',
#  'like': '1,351',
#  'link': 'https://tv.naver.com/v/12818910/list/67096',
#  'program': '백종원의 골목식당',
#  'title': '[3월 18일 예고] “세상 참 거지 같다” 백종원의 눈물…'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '12,896',
#  'like': '49',
#  'link': 'https://tv.naver.com/v/12920770/list/67096',
#  'program': '불타는 청춘',
#  'title': '“화이트데이 때 뭐해요?” 안혜경, 구본승에게 적극적인 대시♥'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,118,244',
#  'like': '8,547',
#  'link': 'https://tv.naver.com/v/12870385/list/67096',
#  'program': '하이에나',
#  'title': '[격렬 엔딩] 김혜수♥주지훈, 어른 섹시 터지는 ‘격정 키스’'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '442,966',
#  'like': '8,739',
#  'link': 'https://tv.naver.com/v/12839194/list/67096',
#  'program': '미스터트롯',
#  'title': '찬또한테 딱!딱! 붙어라♥ 이찬원 ‘딱풀’♫'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '7,187',
#  'like': '18',
#  'link': 'https://tv.naver.com/v/12924290/list/67096',
#  'program': '맛 좀 보실래요',
#  'title': '“남 얘기하듯 하네요” 김정화, 한가림 못마땅하게 여기는 최우석 향한 한마디!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '19,699',
#  'like': '10',
#  'link': 'https://tv.naver.com/v/12923440/list/67096',
#  'program': 'JTBC뉴스',
#  'title': "미국 확진자 5천명 넘어…하루 1천명씩 급증 '도시 마비'"}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '6,027',
#  'like': '14',
#  'link': 'https://tv.naver.com/v/12924472/list/67096',
#  'program': '맛 좀 보실래요',
#  'title': '이덕희, 며느리 안예인 향한 불같은 호통♨'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '5,317',
#  'like': '13',
#  'link': 'https://tv.naver.com/v/12924560/list/67096',
#  'program': '맛 좀 보실래요',
#  'title': '해고당한 서하준, 이슬아 말 떠올리며 ‘억울!’'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '10,682',
#  'like': '48',
#  'link': 'https://tv.naver.com/v/12920596/list/67096',
#  'program': '불타는 청춘',
#  'title': '신효범, 정확한 음정으로 ‘까만 안경’ 한 소절♬ (feat. 김광규 음정 마술사)'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '6,149',
#  'like': '13',
#  'link': 'https://tv.naver.com/v/12924889/list/67096',
#  'program': '맛 좀 보실래요',
#  'title': '서도영, 눈물 흘리며 용서 구하는 이슬아에 ‘굳은 표정’'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '10,197',
#  'like': '53',
#  'link': 'https://tv.naver.com/v/12920708/list/67096',
#  'program': '불타는 청춘',
#  'title': '‘웃음꽃 만개’ 구본승×안혜경, 안구커플의 ♡꽁냥 설거지 타임♥'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '25,728',
#  'like': '48',
#  'link': 'https://tv.naver.com/v/12919593/list/67096',
#  'program': '방법',
#  'title': '저주의 숲으로 몸 옮긴 악귀! 성동일X정지소의 운명은?'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '561,738',
#  'like': '4,795',
#  'link': 'https://tv.naver.com/v/12883353/list/67096',
#  'program': '슈퍼맨이 돌아왔다',
#  'title': '윌벤져스 독립?! 우리 집이 생겼어요!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '29,113',
#  'like': '71',
#  'link': 'https://tv.naver.com/v/12920467/list/67096',
#  'program': '아내의 맛',
#  'title': '최초공개! 트롯둥이 ‘나는 너의 에어백’♬'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '302,783',
#  'like': '2,042',
#  'link': 'https://tv.naver.com/v/12904721/list/67096',
#  'program': 'KBS뉴스',
#  'title': '[크랩] “우리 총리로 오라”…외국에서 더 난리난 장관 인터뷰'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '6,945',
#  'like': '3',
#  'link': 'https://tv.naver.com/v/12926620/list/67096',
#  'program': 'SBSCNBC뉴스',
#  'title': '국내 제약업계, 코로나19 백신·치료제 개발 ‘속도전’'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '8,796',
#  'like': '54',
#  'link': 'https://tv.naver.com/v/12917296/list/67096',
#  'program': '터치플레이TOUCHPLAY',
#  'title': '슛도사 이충희 슛강의'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '28,910',
#  'like': '164',
#  'link': 'https://tv.naver.com/v/12728115/list/67096',
#  'program': '트롯신이 떴다',
#  'title': '[기자간담회 하이라이트] ‘저세상 텐션’ 토크신 강림한 ‘트롯신이 떴다’'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '27,182',
#  'like': '55',
#  'link': 'https://tv.naver.com/v/12919600/list/67096',
#  'program': '방법',
#  'title': '거대한 저주로 인해 멈춰진 일상!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '5,872',
#  'like': '11',
#  'link': 'https://tv.naver.com/v/12924030/list/67096',
#  'program': '골프캐스트TV_골프레슨,골프스윙영상',
#  'title': '[노컷레슨HOWTO골프]비거리늘리는 방법 올바른 릴리스로 바람소리를 만들자/김양아프로'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '8,609',
#  'like': '96',
#  'link': 'https://tv.naver.com/v/12921198/list/67096',
#  'program': '불타는 청춘',
#  'title': '최재훈, 새친구의 스무고개에 심경 복잡 (ft. 금발의 여인 김형준)'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '41,892',
#  'like': '243',
#  'link': 'https://tv.naver.com/v/12902697/list/67096',
#  'program': '개는 훌륭하다',
#  'title': '특별한 개 수업, 시각 장애인 안내견'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '596,420',
#  'like': '7,155',
#  'link': 'https://tv.naver.com/v/12870388/list/67096',
#  'program': '미스터트롯',
#  'title': '♛진(眞)·선(善)♛ ‘영웅이냐 영탁이냐’ 진은 임.영.웅'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '22,933',
#  'like': '66',
#  'link': 'https://tv.naver.com/v/12919525/list/67096',
#  'program': '방법',
#  'title': '＂죽어!＂ 성동일을 향해 분노로 가득 찬 방법 날리는 정지소'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '44,445',
#  'like': '101',
#  'link': 'https://tv.naver.com/v/12906457/list/67096',
#  'program': '이건의 발품스토리 TV',
#  'title': '[간밤현지1면]손흥민, 토트넘 훈련장 복귀! 영국 매체 보도'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '424,777',
#  'like': '6,145',
#  'link': 'https://tv.naver.com/v/12839709/list/67096',
#  'program': '미스터트롯',
#  'title': '할아버지를 향한 그리움..ㅠㅠ 정동원 ‘누가 울어’♩'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '5,506',
#  'like': '12',
#  'link': 'https://tv.naver.com/v/12924584/list/67096',
#  'program': '맛 좀 보실래요',
#  'title': '“나 같은 놈은 죽어야 돼” 서하준, 되는 일 없는 하루에 눈물!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '12,113',
#  'like': '93',
#  'link': 'https://tv.naver.com/v/12920546/list/67096',
#  'program': '불타는 청춘',
#  'title': '‘택사자’ 김형준, 컬투쇼 라이브에 사연 채택??'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '15,387',
#  'like': '71',
#  'link': 'https://tv.naver.com/v/12920176/list/67096',
#  'program': '아내의 맛',
#  'title': '시장 입장과 동시! 즉석 ‘팬사인회’ ٩(♡▽♡ )۶'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '21,876',
#  'like': '41',
#  'link': 'https://tv.naver.com/v/12919698/list/67096',
#  'program': '방법',
#  'title': '저주를 막기 위한 엄지원의 제안 ＂날 방법해＂'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '29,739',
#  'like': '74',
#  'link': 'https://tv.naver.com/v/12919892/list/67096',
#  'program': '방법',
#  'title': '악귀와 연결된 방법사! 엄지원에게 ＂저 언니 방법 못해요＂'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '172,947',
#  'like': '118',
#  'link': 'https://tv.naver.com/v/12865582/list/67096',
#  'program': '아내의 맛',
#  'title': '마마 vs 이웃집 악동들 자비없는 물총 전쟁! 하지만..._아내의 맛 89회 예고'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '7,667',
#  'like': '107',
#  'link': 'https://tv.naver.com/v/12920893/list/67096',
#  'program': '불타는 청춘',
#  'title': '김형준, 18년 만에 슈가맨으로 돌아온 이유 고백☆'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '9,827',
#  'like': '5',
#  'link': 'https://tv.naver.com/v/12923727/list/67096',
#  'program': 'JTBC뉴스',
#  'title': '[든든한 법] "마스크 5980원은 폭리"…첫 환불소송 제기'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '21,646',
#  'like': '62',
#  'link': 'https://tv.naver.com/v/12919380/list/67096',
#  'program': '방법',
#  'title': '＂내 이름 내려!＂ 다급해진 김민재의 절규 #함정_수사_성공!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '11,271',
#  'like': '22',
#  'link': 'https://tv.naver.com/v/12924972/list/67096',
#  'program': '맛 좀 보실래요',
#  'title': '[93회 예고] 심이영, 본격적으로 시누이 노릇하나?!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '8,107',
#  'like': '22',
#  'link': 'https://tv.naver.com/v/12920674/list/67096',
#  'program': '불타는 청춘',
#  'title': '“오리고기엔 부추지” 김광규, 올지 안 올지 모를 최재훈을 기다리며 설레발!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '516,006',
#  'like': '7,613',
#  'link': 'https://tv.naver.com/v/12839883/list/67096',
#  'program': '미스터트롯',
#  'title': '음악에 대한 갈망.. 영탁 ‘내 삶의 이유있음은’♫'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '21,744',
#  'like': '52',
#  'link': 'https://tv.naver.com/v/12919833/list/67096',
#  'program': '방법',
#  'title': '저주로 물든 삶을 사는 모녀의 눈물!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '10,769',
#  'like': '2',
#  'link': 'https://tv.naver.com/v/12925440/list/67096',
#  'program': '연합뉴스TV',
#  'title': '[속보] 서울시 117만 7천가구에 최대 50만원 긴급지원'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '61,229',
#  'like': '9',
#  'link': 'https://tv.naver.com/v/12923811/list/67096',
#  'program': 'JTBC뉴스',
#  'title': "초등생 성폭행 뒤 협박한 고등학생…'소년법 적용' 논란"}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '28,746',
#  'like': '54',
#  'link': 'https://tv.naver.com/v/12916213/list/67096',
#  'program': 'IB SPORTS',
#  'title': '언더테이커, 알리스터 블랙의 든든한 지원군_일리미네이션 챔버_2020'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '931,859',
#  'like': '8,526',
#  'link': 'https://tv.naver.com/v/12840081/list/67096',
#  'program': '미스터트롯',
#  'title': '최저점이 94점 ㅎㄷㄷ; 점수판 실화..? 점수의 배신자'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '37,194',
#  'like': '62',
#  'link': 'https://tv.naver.com/v/12864568/list/67096',
#  'program': '김형준의 인사이드MLB',
#  'title': '다저스가 놓친 최고의 선수들 | 김형준'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '4,592',
#  'like': '11',
#  'link': 'https://tv.naver.com/v/12924777/list/67096',
#  'program': '맛 좀 보실래요',
#  'title': '심이영, 서도영×이슬아 ‘한 집 살이’에 감추지 못하는 불안함!'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '5,881',
#  'like': '38',
#  'link': 'https://tv.naver.com/v/12916173/list/67096',
#  'program': '골프캐스트TV_골프레슨,골프스윙영상',
#  'title': '[노컷레슨HOWTO골프]백스윙 가동범위를 늘리는 하체움직임/안소영프로'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '22,689',
#  'like': '35',
#  'link': 'https://tv.naver.com/v/12914122/list/67096',
#  'program': '헤럴드스토리',
#  'title': '샴푸 먹고 비누 씹고 신천기 탈출기 직접 들어봤다 l 팩트체커'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '163,793',
#  'like': '2,720',
#  'link': 'https://tv.naver.com/v/12883730/list/67096',
#  'program': '슈퍼맨이 돌아왔다',
#  'title': '위기의 벤파이, 유혹을 이겨낼 수 있을까?'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '959',
#  'like': '0',
#  'link': 'https://tv.naver.com/v/12926136/list/67096',
#  'program': '연합뉴스TV',
#  'title': "[뉴스특보] 전국 유·초중고 개학 추가 연기…초유의 '4월 개학'"}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '3,889',
#  'like': '4',
#  'link': 'https://tv.naver.com/v/12924538/list/67096',
#  'program': 'SBS뉴스',
#  'title': '[친절한 경제] 자영업자 부가세 감면·면제, 적용 대상은?'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '11,701',
#  'like': '42',
#  'link': 'https://tv.naver.com/v/12920404/list/67096',
#  'program': '아내의 맛',
#  'title': '나난나나나~♪ 무한 ‘다시’ ๑블랙홀๑'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '6,498',
#  'like': '99',
#  'link': 'https://tv.naver.com/v/12920845/list/67096',
#  'program': '불타는 청춘',
#  'title': '‘너구리와 댕댕이’ 김형준×최민용의 불 피우며 꺼내는 솔직 토크'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '16,444',
#  'like': '1',
#  'link': 'https://tv.naver.com/v/12923954/list/67096',
#  'program': 'JTBC뉴스',
#  'title': 'WHO "코로나19에 소염제 이부프로펜 복용 위험"'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '6,356',
#  'like': '34',
#  'link': 'https://tv.naver.com/v/12921726/list/67096',
#  'program': '정철우의 야구 맛집',
#  'title': 'LG 우승 가능할까? 박용택에게 물었더니...'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '22,807',
#  'like': '49',
#  'link': 'https://tv.naver.com/v/12919528/list/67096',
#  'program': '방법',
#  'title': '성동일VS정지소!  한 치의 양보 없는 정면 대결'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '154,181',
#  'like': '1,100',
#  'link': 'https://tv.naver.com/v/12883499/list/67096',
#  'program': '슈퍼맨이 돌아왔다',
#  'title': '“난 다 가졌어.. 널 가진 이후로”(feat.널 좋아해♬)'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '652,425',
#  'like': '4,951',
#  'link': 'https://tv.naver.com/v/12583703/list/67096',
#  'program': '미스터트롯',
#  'title': '칼 갈고 나온 장민호 ‘상사화’♪ #감탄 #심취'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,885,270',
#  'like': '19,346',
#  'link': 'https://tv.naver.com/v/12116952/list/67096',
#  'program': '미스터트롯',
#  'title': '임영웅 ‘일편단심 민들레야’♪ #안정 #섬세 #완벽 #✌'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '135,296',
#  'like': '759',
#  'link': 'https://tv.naver.com/v/12883541/list/67096',
#  'program': '슈퍼맨이 돌아왔다',
#  'title': '엄마를 향한 연우의 애틋한 영상편지♡'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '67,284',
#  'like': '594',
#  'link': 'https://tv.naver.com/v/12918990/list/67096',
#  'program': '날씨가 좋으면 찾아가겠어요',
#  'title': '[7회 예고] 좋아해서 고백한 게 뭐가 잘못이죠?'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '70,815',
#  'like': '258',
#  'link': 'https://tv.naver.com/v/12903088/list/67096',
#  'program': '동상이몽2_너는 내 운명',
#  'title': '“나도 아직 엄마가 필요하구나” 박시은, 엄마가 돼서야 알게 된 엄마 마음♥'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '3,309',
#  'like': '5',
#  'link': 'https://tv.naver.com/v/12923826/list/67096',
#  'program': 'JTBC뉴스',
#  'title': '[맞장토론] 코로나19 추경, 국회 본회의 통과…남은 과제는?'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '149,543',
#  'like': '511',
#  'link': 'https://tv.naver.com/v/12910257/list/67096',
#  'program': 'KTV 국민방송',
#  'title': '전국 유초중고 개학 2주 추가연기, 4월 6일 개학 - 교육부 브리핑 3/17(화)'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '1,798,165',
#  'like': '16,961',
#  'link': 'https://tv.naver.com/v/11725060/list/67096',
#  'program': '미스터트롯',
#  'title': '♨참가자 견제 1순위♨ 노사연 기립박수↗ 임영웅 ‘바램’ ♫'}
# 2020-03-18 13:59:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://tv.naver.com/r/>
# {'count': '7,154',
#  'like': '32',
#  'link': 'https://tv.naver.com/v/12920800/list/67096',
#  'program': '불타는 청춘',
#  'title': '‘학창시절 인기남’ 최성국의 느끼한 밸런타인데이 일화 재현☆'}
# 2020-03-18 13:59:01 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-03-18 13:59:01 [scrapy.extensions.feedexport] INFO: Stored csv feed (100 items) in: items.csv
# 2020-03-18 13:59:01 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 213,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 32059,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.957937,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 3, 18, 4, 59, 1, 470160),
#  'item_scraped_count': 100,
#  'log_count/DEBUG': 101,
#  'log_count/INFO': 11,
#  'memusage/max': 61403136,
#  'memusage/startup': 61403136,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 3, 18, 4, 59, 0, 512223)}
# 2020-03-18 13:59:01 [scrapy.core.engine] INFO: Spider closed (finished)
